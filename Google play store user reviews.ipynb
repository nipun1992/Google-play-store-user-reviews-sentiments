# %% [markdown]
# #### Importing the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Reading the csv as dataframe

# %%
df = pd.read_csv('googleplaystore_user_reviews.csv')

# %%
df.head(5)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# *We will perform sentiment analysis on Google Play store user reviews*

# %% [markdown]
# #### Renaming the column

# %%
df = df.rename(columns={'Translated_Review':'Reviews'})

# %%
df.columns
# Out:
# Index(['App', 'Reviews', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %% [markdown]
# *The column **Translated_Review** has been renamed to **Reviews**.*

# %% [markdown]
# #### Checking information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Reviews                 37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# *There are total of 64295 rocords and 5 columns in the dataset*

# %%
df.isnull().sum()
# Out:
# App                           0
# Reviews                   26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %% [markdown]
# *There are 26868 missing values in **Reviews** column and 26863 missing values in **Sentiment**, **Sentiment_Polarity** and **Sentiment_Subjectivity** columns of the dataset.*

# %% [markdown]
# #### Checking for duplicate records

# %%
df.duplicated(subset=None, keep='first').sum()
# Out:
# 33616

# %% [markdown]
# *There are 33616 duplicate rows*

# %%
df.shape
# Out:
# (64295, 5)

# %%
df = df[df.duplicated(df.columns.tolist(), keep='first')==False]

# %%
df.duplicated(subset=None, keep='first').sum()
# Out:
# 0

# %%
df.shape
# Out:
# (30679, 5)

# %% [markdown]
# *The duplicate rows have been removed*

# %%
df.isnull().sum()
# Out:
# App                         0
# Reviews                   987
# Sentiment                 982
# Sentiment_Polarity        982
# Sentiment_Subjectivity    982
# dtype: int64

# %% [markdown]
# #### Handling missing values in  Reviews column

# %%
df[(df['Reviews'].isnull())].loc[:, 'App']
# Out:
# 2                                   10 Best Foods for You
# 268                                                  11st
# 362                       1LINE – One Line with One Touch
# 405      2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif
# 539                   2Date Dating App, Love and matching
#                                ...
# 64082      Hotspot Shield Free VPN Proxy & Wi-Fi Security
# 64119                                             Hotstar
# 64156                      Hotwire Hotel & Car Rental App
# 64202                      Housing-Real Estate & Property
# 64236                         Houzz Interior Design Ideas
# Name: App, Length: 987, dtype: object

# %% [markdown]
# *The above displays the rows for which there are missing values in **Reviews** column*

# %%
df[(df['Reviews'].isnull())].loc[:, 'App'].unique()
# Out:
# array(['10 Best Foods for You', '11st', '1LINE – One Line with One Touch',
#        '2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif',
#        '2Date Dating App, Love and matching', '2RedBeans',
#        '30 Day Fitness Challenge - Workout at Home',
#        '365Scores - Live Scores', '3D Blue Glass Water Keyboard Theme',
#        '3D Color Pixel by Number - Sandbox Art Coloring',
#        '3D Live Neon Weed Launcher', '4 in a Row',
#        '4K Wallpapers and Ultra HD Backgrounds',
#        '591房屋交易-租屋、中古屋、新建案、實價登錄、別墅透天、公寓套房、捷運、買房賣房行情、房價房貸查詢', '591房屋交易-香港',
#        '7 Cups: Anxiety & Stress Chat', '7 Day Food Journal Challenge',
#        '7 Minute Workout', '7 Weeks - Habit & Goal Tracker',
#        '8 Ball Pool', '850 Sports News Digest',
#        '8fit Workouts & Meal Planner', '95Live -SG#1 Live Streaming App',
#        'A Call From Santa Claus!', 'A Manual of Acupuncture',
#        'A Word A Day', 'A&E - Watch Full Episodes of TV Shows',
#        'A+ Gallery - Photos & Videos', 'A+ Mobile',
#        'ABC Kids - Tracing & Phonics', 'ABC News - US & World News',
#        'ABC Preschool Free', 'ABCmouse.com',
#        'AC - Tips & News for Android™', 'ACE Elite',
#        'AD - Nieuws, Sport, Regio & Entertainment',
#        'ADP Mobile Solutions', 'ADW Launcher 2', 'AMC Theatres', 'ANA',
#        'AOL - News, Mail & Video', 'AP Mobile - Breaking News',
#        'APE Weather ( Live Forecast)',
#        'APUS Launcher - Theme, Wallpaper, Hide Apps', 'ARY NEWS',
#        'ARY NEWS URDU', 'ASOS', 'ASUS Calling Screen',
#        'ASUS Cover for ZenFone 2', 'ASUS Gallery', 'ASUS Quick Memo',
#        'ASUS Sound Recorder', 'ASUS SuperNote',
#        'AT&T Navigator: Maps, Traffic', 'AT&T Smart Wi-Fi',
#        'AT&T Visual Voicemail',
#        'AVG Cleaner – Speed, Battery & Memory Booster',
#        'Abs Training-Burn belly fat', 'Account Manager',
#        'Accounting App - Zoho Books',
#        'AccuWeather: Daily Forecast & Live Weather Reports',
#        'Acorn TV: World-class TV from Britain and Beyond',
#        'Acorns - Invest Spare Change', 'Acupuncture Assistant',
#        'AdWords Express', 'Ada - Your Health Guide', 'Add Text To Photo',
#        'Adobe Acrobat Reader',
#        'Adobe Photoshop Express:Photo Editor Collage Maker',
#        'Adult Dating - AdultFinder',
#        'Adult Glitter Color by Number Book - Sandbox Pages',
#        'Advanced Task Killer', 'Agar.io', 'Age Calculator',
#        'Agoda – Hotel Booking Deals', 'Air Traffic', 'AirAsia',
#        'AirBrush: Easy Photo Editor', 'Airbnb',
#        'Airport + Flight Tracker Radar',
#        'Airway Ex - Intubate. Anesthetize. Train.', 'Akinator',
#        'AlReader -any text book reader', 'Alarm Clock',
#        'Alarm Clock Free', 'Alfred Home Security Camera',
#        'AliExpress - Smarter Shopping, Better Living',
#        'All Email Providers', 'All Events in City',
#        'All Football - Latest News & Videos',
#        'All Football GO- Live Score, Games',
#        'All Language Translator Free', 'All Maths Formulas',
#        'All Mental disorders', 'All Social Networks',
#        'All Video Downloader 2018',
#        'All-In-One Toolbox: Cleaner, Booster, App Manager',
#        'All-in-One Mahjong 3 FREE',
#        'AllTrails: Hiking, Running & Mountain Bike Trails', 'Allegiant',
#        'Allrecipes Dinner Spinner', "Alto's Adventure", 'Amazon Drive',
#        'Amazon FreeTime – Kids’ Videos, Books, & TV shows',
#        'Amazon Kindle', 'Amazon Prime Video', 'Amazon Shopping',
#        'Amazon for Tablets', 'American Airlines', 'Amex Mobile',
#        'Amino: Communities and Chats', 'Amtrak',
#        'Anatomy Learning - 3D Atlas', 'Ancestry',
#        'AndroZip™ FREE File Manager',
#        'Android Auto - Maps, Media, Messaging & Voice',
#        'Android Messages', 'Anger of stick 5 : zombie', 'Angry Birds 2',
#        'Angry Birds Classic', 'Angry Birds Rio',
#        'Animal Jam - Play Wild!', 'Animal Planet GO',
#        'Animated Photo Editor',
#        'Anime Avatar Creator: Make Your Own Avatar',
#        'Anime Manga Coloring Book', 'Anthem Anywhere',
#        'Anthem BC Anywhere',
#        'Any.do: To-do list, Calendar, Reminders & Planner',
#        'Apartment Decorating Ideas',
#        'Apartment List: Housing, Apt, and Property Rentals',
#        'Apartment, Home Rental Search: Realtor.com Rentals',
#        'Apartments & Rentals - Zillow', 'Apartments.com Rental Search',
#        'Apex Launcher', 'Apk Installer', 'App vault', 'AppLock',
#        'AppLock - Fingerprint', 'Apple Daily 蘋果動新聞',
#        'Aprender inglés con Wlingua', 'Archos File Manager', 'Arrow.io',
#        'Asana: organize team projects', 'Ascape VR: 360° Virtual Travel',
#        'Asphalt 8: Airborne', 'Associated Credit Union Mobile',
#        'Asteroids 3D live wallpaper',
#        'Atlan3D Navigation: Korea navigator',
#        'AutoCAD - DWG Viewer & Editor',
#        'AutoScout24 Switzerland – Find your new car',
#        'Avakin Life - 3D virtual world', 'Aviary Effects: Classic',
#        'Aviary Stickers: Free Pack', 'Azar', 'Azpen eReader',
#        'B612 - Beauty & Filter Camera', 'BBC Media Player', 'BBC News',
#        'BBC Sport', 'BBM - Free Calls & Messages', 'BBVA Compass Banking',
#        'BBVA Spain', 'BBW Dating & Curvy Singles Chat- LargeFriends',
#        'BBW Dating & Plus Size Chat', 'BBWCupid - BBW Dating App',
#        'BELONG Beating Cancer Together', 'BEST CAR SOUNDS',
#        'BET NOW - Watch Shows', 'BEYBLADE BURST app', 'BZWBK24 mobile',
#        'BaBe - Baca Berita', 'BaBe Lite - Baca Berita Hemat Kuota',
#        'BaBe+ - Berita Indonesia', 'Babbel – Learn Languages',
#        'Babbel – Learn Spanish',
#        'Baby ABC in box! Kids alphabet games for toddlers!',
#        'Baby Monitor', 'Baby Name Together', 'Baby Panda Care',
#        'Baby Panda Learns Shapes', 'Baby Panda Musical Genius',
#        'Baby Panda’s Juice Shop',
#        'Baby Sleep: White noise lullabies for newborns',
#        'Baby Tiger Care - My Cute Virtual Pet Friend', 'Baby puzzles',
#        'Baca- Berita Terbaru, Informasi, Gosip dan Politik',
#        'Backgrounds (HD Wallpapers)', 'Backgrounds HD (Wallpapers)',
#        'BaconReader for Reddit', 'Bad Piggies',
#        'Bagan - Myanmar Keyboard', 'Bangla Newspaper – Prothom Alo',
#        'Banjo', 'Bank of America Mobile Banking', 'BankMobile Vibe App',
#        'Banorte Movil', 'Banque Populaire', 'Barbie Life™',
#        'Barbie Magical Fashion', 'Barbie™ Fashion Closet',
#        'Barcode Scanner',
#        'Basketball FRVR - Shoot the Hoop and Slam Dunk!',
#        'Basketball Stars', 'Battlelands Royale', 'Be A Legend: Soccer',
#        'BeSoccer - Soccer Live Score', 'BeWild Free Dating & Chat App',
#        'Beautiful Design Birthday Cake', 'Beautiful Widgets Pro',
#        'Beauty Camera - Selfie Camera',
#        'Beauty Makeup Snappy Collage Photo Editor - Lidow',
#        'Beauty Makeup – Photo Makeover', 'Beauty Selfie Camera',
#        'BeautyPlus - Easy Photo Editor & Selfie Camera',
#        'Bed Time Fan - White Noise Sleep Sounds',
#        'Bedroom Decorating Ideas', 'Been Together (Ad) - D-day',
#        'Best Buy', 'Best Car Wallpapers',
#        'Best Fiends - Free Puzzle Game',
#        'Best New Ringtones 2018 Free 🔥 For Android™',
#        'Best Ovulation Tracker Fertility Calendar App Glow',
#        'Best Wallpapers Backgrounds(100,000+ 4K HD)',
#        'Best Wallpapers QHD',
#        'BestCam Selfie-selfie, beauty camera, photo editor',
#        'BetterMe: Weight Loss Workouts', 'BeyondMenu Food Delivery',
#        'Bible', 'Big Days - Events Countdown',
#        'Bike Computer - GPS Cycling Tracker', 'Binaural Beats Therapy',
#        'BioLife Plasma Services', 'Birdays – Birthday reminder',
#        'Birds Sounds Ringtones & Wallpapers',
#        'Black People Meet Singles Date',
#        'Black Wallpaper, AMOLED, Dark Background: Darkify',
#        'Black White Interracial Dating - Interracial Match',
#        "Blackpink as if it's your last",
#        'Bleacher Report: sports news, scores, & highlights',
#        'Blendr - Chat, Flirt & Meet', 'Blibli.com Belanja Online',
#        'Blidz - Hunt Free Deals On Trending Items!',
#        'Blinkist - Nonfiction Books', 'Blitzer.de',
#        'Block Craft 3D: Building Simulator Games For Free',
#        'Block Puzzle', 'Block Puzzle Classic Legend !',
#        'Blogaway for Android (Blogger)', 'Blogger', "Bloglovin'",
#        'Blood Donor', 'Blood Pressure', 'Blossom Blast Saga', 'BluTV',
#        'Blue CareOnDemand', 'BlueJeans for Android',
#        'Bluebird by American Express', 'Blur Image Background',
#        'Blur Image Background Editor (Blur Photo Editor)', 'Bowmasters',
#        'Box', "Boys Photo Editor - Six Pack & Men's Suit",
#        'Breaking News, Local news, Attacks and Alerts Free',
#        'Breathing Zone', 'Bricks n Balls',
#        'Brightest Flashlight - LED Light', 'Brightest Flashlight Free ®',
#        'Brightest LED Flashlight', 'Brilliant', 'Brit + Co',
#        'British Airways', 'Browser 4G', 'Bualuang mBanking',
#        'Bubble Shooter', 'Bubble Shooter 2', 'Bubble Shooter Genies',
#        'Bubble Shooter Space', 'Bubble Witch 3 Saga', 'Buienradar - weer',
#        'Build a Bridge!', 'Bukalapak - Jual Beli Online',
#        'BukuBayi - Perkembangan Bayi', 'Burner - Free Phone Number',
#        'Bus Rush: Subway Edition', 'Buscapé - Ofertas e descontos',
#        'Business Calendar 2', 'Butterfly Live Wallpaper',
#        'Buzz Launcher-Smart&Free Theme', 'BuzzFeed: News, Tasty, Quizzes',
#        'BÁO MỚI - Đọc Báo, Tin Tức 24h', 'C Programming',
#        'C++ Programming', 'C++ Tutorials', 'CAIXA',
#        'CALCU™ Stylish Calculator Free', 'CATS: Crash Arena Turbo Stars',
#        'CBS - Full Episodes & Live TV', 'CBS News',
#        'CBS Sports App - Scores, News, Stats & Watch Live',
#        'CBS Sports Fantasy', 'CDL Practice Test 2018 Edition',
#        'CIA - Caller ID & Call Blocker',
#        'CM Browser - Ad Blocker , Fast Download , Privacy',
#        'CM FILE MANAGER HD', 'CM Flashlight (Compass, SOS)',
#        'CM Launcher 3D - Theme, Wallpapers, Efficient',
#        'CM Locker - Security Lockscreen', 'CMB Free Dating App',
#        'CNBC: Breaking Business News & Live Market Data',
#        'CNN Breaking US & World News', "COOKING MAMA Let's Cook!",
#        'CVS Caremark', 'CW Seed', 'CWT To Go',
#        'Cache Cleaner-DU Speed Booster (booster & cleaner)',
#        'Caf - Mon Compte', 'Calculator', 'Calculator ++',
#        'Calculator - free calculator ,multi calculator app',
#        'Calculator - free calculator, multi calculator app',
#        'Calculator - unit converter', 'Calculator Plus Free',
#        'Calculator with Percent (Free)', 'Calendar Widget Month + Agenda',
#        'Calendar+ Schedule Planner App', 'Call Blocker',
#        'Call Control - Call Blocker', 'Call Free – Free Call',
#        'Call of Duty:Black Ops Zombies',
#        'CallApp: Caller ID, Blocker & Phone Call Recorder', 'Caller ID +',
#        'Calls & Text by Mo+', 'Calls Blacklist - Call Blocker',
#        'Calm - Meditate, Sleep, Relax', 'Calorie Counter & Diet Tracker',
#        'Calorie Counter - EasyFit free', 'Calorie Counter - MyFitnessPal',
#        'Calorie Counter - MyNetDiary', 'Calorie Counter by FatSecret',
#        'Camera FV-5', 'Camera FV-5 Lite',
#        'Camera MX - Free Photo & Video Camera', 'Camera ZOOM FX - FREE',
#        'Camera for Android', 'Camera360 Lite - Selfie Camera',
#        'Camera360: Selfie Photo Editor with Funny Sticker',
#        'Camera51 - a smarter camera', 'Cameringo Lite. Filters Camera',
#        'Candy Bomb', 'Candy Camera - selfie, beauty camera, photo editor',
#        'Candy Crush Jelly Saga', 'Candy Crush Soda Saga', 'Candy Day',
#        'Candy selfie - photo editor, live filter camera',
#        'Canva: Poster, banner, card maker & graphic design',
#        'Canvas Student', 'Capital One® Mobile', 'Capitec Remote Banking',
#        'CarMax – Cars for Sale: Search Used Car Inventory',
#        'Card Wars - Adventure Time', 'Cardboard', 'CareZone',
#        'Carousell: Snap-Sell, Chat-Buy', 'Cars: Lightning League',
#        'Cartoon Network App', 'Cash App',
#        'Cash, Inc. Money Clicker Game & Business Adventure',
#        'Castle Clash: Heroes of the Empire US', 'Castlight Mobile',
#        'Casual Dating & Adult Singles - Joyride',
#        'Cat Sim Online: Play with Cats', 'Caviar - Food Delivery',
#        'Chapters: Interactive Stories',
#        'Chat Rooms, Avatars, Date - Galaxy', 'ChatVideo Meet new people',
#        'Cheap Flights & Hotels momondo',
#        'Cheap hotel deals and discounts — Hotellook',
#        'CheapTickets – Hotels, Flights & Travel Deals',
#        'Cheapflights – Flight Search', 'Checkers ✔️',
#        'Checkout 51: Grocery coupons', 'ChefTap Recipes & Grocery List',
#        'Chefkoch - Rezepte & Kochen', 'Chegg Study - Homework Help',
#        'Chess Free', 'Chess PRO Free', 'Chess School for Beginners',
#        'Chess for Kids - Play & Learn', 'Chicago Tribune', 'Chick-fil-A',
#        'Chictopia', 'Chilindo', 'Chime - Mobile Banking',
#        'Chispa, the Dating App for Latino, Latina Singles',
#        'Choice Hotels', 'Choices: Stories You Play',
#        'Christian Dating For Free App', 'Chrome Beta', 'Chrome Dev',
#        'Cisco Webex Meetings', 'Citibanamex Movil',
#        'Citizens Bank Mobile Banking', 'Clash Royale', 'Clash of Clans',
#        'ClassDojo', 'Classic Calculator', 'Classical music for baby',
#        'ClearCareGo Caregiver', 'ClickMeeting Webinars', 'Cloud Print',
#        'Clover Dating App', 'Club Factory Everything, Unbeaten Price',
#        'Clue', 'Collage&Add Stickers papelook',
#        'Color Call - Caller Screen, LED Flash', 'Color Flashlight',
#        'Color Road', 'Color Touch Effects',
#        'Color by Number - Draw Sandbox Pixel Art',
#        'Color by Number – New Coloring Book',
#        'ColorFil - Adult Coloring Book', 'ColorNote Notepad Notes',
#        'ColorSnap® Visualizer', 'Colorfit - Drawing & Coloring',
#        'Colorful Glitter Neon Butterfly Keyboard Theme',
#        'Colorfy: Coloring Book for Adults - Free', 'Coloring & Learn',
#        'Coloring book moana', 'Common Core', 'CompTIA A+ Pocket Prep',
#        'CompTIA Exam Training', 'Compass', 'Comptia A+ 220-901 & 220-902',
#        'ConnectLine', 'Contacts', 'Contacts+', 'Cookbook Recipes',
#        'Cooking Channel', 'Cooking Fever',
#        "Cooking Madness - A Chef's Restaurant Games", 'Cookpad',
#        'Cool Popular Ringtones 2018 🔥', 'Cool Reader',
#        'Couch to 5K by RunDouble', 'Couchsurfing Travel App',
#        'Cougar Dating Life : Date Older Women Sugar Mummy',
#        'Couple - Relationship App', 'Coupon Sherpa',
#        'Coupons.com – Grocery Coupons & Cash Back Savings',
#        'Coursera: Online courses',
#        'Cover Fire: offline shooting games for free',
#        'Cozi Family Organizer', 'CppDroid - C/C++ IDE',
#        'Crackle - Free TV & Movies', 'Crazy Colors: Bubbles Matching',
#        'Create A Superhero HD', 'Creative Ideas - DIY & Craft',
#        'Credit Karma', 'Credit Sesame', 'CreditWise from Capital One',
#        'Cricbuzz - Live Cricket Scores & News', 'Crossy Road',
#        'Curriculum vitae App CV Builder Free Resume Maker',
#        'Curso de Ingles Gratis', 'Cut the Rope 2',
#        'Cut the Rope FULL FREE', 'Cute Pet Puppies',
#        'Cute wallpapers & kawaii backgrounds images',
#        'Cycling - Bike Tracker',
#        'Cymera Camera- Photo Editor, Filter,Collage,Layout',
#        'Czech Public Transport IDOS', 'DC Comics', 'DC Super Hero Girls™',
#        'DEAD TARGET: FPS Zombie Apocalypse Survival Games',
#        'DEER HUNTER 2018', 'DELISH KITCHEN - 無料レシピ動画で料理を楽しく・簡単に！',
#        'DINO HUNTER: DEADLY SHORES', 'DIY Garden Ideas',
#        'DIY On A Budget', 'DMV Permit Practice Test 2018 Edition',
#        'DRAGON BALL LEGENDS', 'DSLR Camera Hd Ultra Professional',
#        'DStv Now', 'DU Recorder – Screen Recorder, Video Editor, Live',
#        'DaBang - Rental Homes in Korea', 'Daily Mail Online',
#        'Daily Manga - Comic & Webtoon',
#        'Daily Workouts - Exercise Fitness Routine Trainer',
#        'Daily Yoga - Yoga Fitness Plans',
#        'Dailyhunt (Newshunt) - Latest News, Viral Videos', 'Dairy Queen',
#        'Daniel Tiger for Parents', 'DashClock Widget',
#        'Dashlane Free Password Manager',
#        'Dating App, Flirt & Chat : W-Match',
#        'Dating for 50 plus Mature Singles – FINALLY', 'Daum Mail - 다음 메일',
#        "Davis's Drug Guide", "Davis's Drug Guide for Nurses",
#        'Debonairs Pizza', 'Deep Sleep and Relax Hypnosis',
#        'Delivery Club–Доставка еды:пицца,суши,бургер,салат',
#        'Despegar.com Hoteles y Vuelos', 'Device Help',
#        'Diabetes & Diet Tracker', 'Diabetes:M',
#        'Diamond Zipper Lock Screen', 'Diary with lock',
#        'Diary with lock password',
#        'Dice With Buddies™ Free - The Fun Social Dice Game',
#        'Dictionary - Merriam-Webster', 'Die TK-App – alles im Griff',
#        'Digg', 'DigiCal Calendar Agenda',
#        'Digit Save Money Automatically', 'Digital Alarm Clock', 'Dil Mil',
#        'Dino War: Rise of Beasts', 'Dinosaur Simulator: Dino World',
#        'Discover Mobile', 'Disney Crossy Road',
#        'Disney Heroes: Battle Mode',
#        'Disney Magic Kingdoms: Build Your Own Magical Park',
#        'DisneyNOW – TV Shows & Games', 'Divar',
#        'Do It Later: Tasks & To-Dos', 'Docs To Go™ Free Office Suite',
#        'Doctor On Demand', 'Doctor Pets', 'Dog Licks Screen Wallpaper',
#        'Dog Run - Pet Dog Simulator', 'Dog Sim Online: Raise a Family',
#        'Dollhouse Decorating Games',
#        'Dolphin Browser - Fast, Private & Adblock🐬',
#        'Dolphins Live Wallpaper', "Domino's Pizza USA", 'Dominos Game ✔️',
#        'Domofond Недвижимость. Купить, снять квартиру.', 'Doodle Jump',
#        'Door Lock Screen', 'Dosecast - Medication Reminder',
#        'Dr. Oetker Rezeptideen', "Dr. Panda & Toto's Treehouse",
#        'Dr. Panda Restaurant 3', 'Dr. Panda Town: Vacation',
#        'DraftKings - Daily Fantasy Sports', 'Dragon Hills',
#        'Dragon Sim Online: Be A Dragon',
#        'DramaFever: Stream Asian Drama Shows & Movies', 'Draw A Stickman',
#        'Draw In', 'Draw Your Game', 'Draw a Stickman: EPIC 2',
#        'Draw.ly - Color by Number Pixel Art Coloring',
#        'Drawing Clothes Fashion Ideas',
#        'Drawing for Kids Learning Games for Toddlers age 3',
#        'Dream League Soccer 2018', 'DreamMapper', 'DreamTrips',
#        'DreamWorks Friends', 'Dresses Ideas & Fashions +3000',
#        'DroidAdmin for Android - Advice', 'Dropbox',
#        'Drugs.com Medication Guide', 'Dude Perfect 2',
#        'Dumb Ways to Die 2: The Games', "Dunkin' Donuts", 'DuraSpeed',
#        'E*TRADE Mobile', 'EMT Review Plus',
#        'EMT Tutor NREMT-B Study Guide', 'EMT-B Pocket Prep',
#        'ES File Explorer File Manager', 'ESPN', 'ESPN Fantasy Sports',
#        'Earn to Die 2', 'Easy - taxi, car, ridesharing',
#        'Easy Healthy Recipes', 'Easy Installer - Apps On SD',
#        'Easy Makeup Tutorials', 'Easy Origami Ideas',
#        'Easy Voice Recorder', 'EasyBib: Citation Generator',
#        'EatStreet Food Delivery App',
#        'Ebates: Cash Back, Coupons, Rewards & Savings', 'Ebook Reader',
#        'Ecobank Mobile Banking', 'Edmodo', 'Educational Games 4 Kids',
#        'Educational Games for Kids', 'El tiempo de AEMET',
#        'Elevate - Brain Training Games',
#        'EliteSingles – Dating for Single Professionals',
#        'Elmo Calls by Sesame Street', 'Email TypeApp - Mail App',
#        'Emmanuella Funny Videos 2018',
#        'Emoji Keyboard - Cute Emoji,GIF, Sticker, Emoticon',
#        'Emoji keyboard - Cute Emoticons, GIF, Stickers',
#        'Endless Numbers', 'Endomondo - Running & Walking',
#        'English Dictionary - Offline',
#        'English Grammar Complete Handbook', 'English Grammar Test',
#        'English Persian Dictionary', 'English to Urdu Dictionary',
#        'English with Lingualeo', 'English-Myanmar Dictionary', 'Entel',
#        'Enterprise Rent-A-Car', 'Episode - Choose Your Story',
#        'Equestria Girls', 'Etsy: Handmade & Vintage Goods', 'Etta Homes',
#        'Eurosport', 'Eve Period Tracker - Love, Sex & Relationships App',
#        'Even - organize your money, get paid early',
#        'Events High - Meet Your City!', 'Ever After High™ Charmed Style',
#        'Everlance: Free Mileage Log',
#        'Evernote – Organizer, Planner for Notes & Memos', 'Evie Launcher',
#        'ExDialer - Dialer & Contacts',
#        'Expedia Hotels, Flights & Car Rental Travel Deals',
#        'Expense IQ Money Manager', 'Experian - Free Credit Report',
#        'Extreme Car Driving Simulator', 'Extreme Coupon Finder',
#        'Extreme Match', 'Extreme Racing 2 - Real driving RC cars game!',
#        'EyeCloud', 'EyeEm - Camera & Photo Filter', 'EzCalculator',
#        'FBReader: Favorite Book Reader', 'FERZU - Furries Social Network',
#        'FIFA - Tournaments, Soccer News & Live Scores',
#        'FINAL FANTASY BRAVE EXVIUS', 'FOX',
#        'FOX NOW - On Demand & Live TV',
#        'FOX Sports: Live Streaming, Scores & News', 'FP Notebook',
#        'FREE LIVE TALK', 'FREE Stock Market Trading Tips',
#        'FREEDOME VPN Unlimited anonymous Wifi Security',
#        'FUN Keyboard – Emoji Keyboard, Sticker,Theme & GIF',
#        'Fabulous: Motivate Me! Meditate, Relax, Sleep',
#        'Face Filter, Selfie Editor - Sweet Camera', 'Facebook',
#        'Facebook Ads Manager', 'Facebook Lite', 'Facebook Local',
#        'Facebook Pages Manager', 'Facetune - Ad Free',
#        'Fair: A New Way To Own A Car', 'Fake Call - Fake Caller ID',
#        'Fallout Shelter',
#        'Family Album Mitene: Private Photo & Video Sharing',
#        'Family Dollar',
#        'Family GPS Tracker and Chat + Baby Monitor Online',
#        'Family GPS tracker KidControl + GPS by SMS Locator',
#        'Family Locator - GPS Tracker', 'FamilySearch Tree',
#        'FanDuel: Daily Fantasy Sports', 'Fancy', 'Fancy Widgets',
#        'Fandango Movies - Times + Tickets', 'Fantasy Football',
#        'Fantasy Football & NFL News', 'Fantasy Football Manager (FPL)',
#        'Farm Fruit Pop: Party Time', 'Farm Heroes Saga',
#        'FarmersOnly Dating', 'Farming Simulator 14',
#        'Farming Simulator 18', 'Fashion in Vogue', 'Fast News',
#        'Fast Scanner : Free PDF Scan', 'Fast Secure VPN',
#        'FastMeet: Chat, Dating, Love',
#        'Fat Burning Workout - Home Weight lose',
#        'Fate/Grand Order (English)', 'Faustop Sounds',
#        'Feed Baby - Baby Tracker', 'Fertility Friend Ovulation App',
#        'Fever', 'FidMe Loyalty Cards & Deals at Grocery Supermarket',
#        'File Browser by Astro (File Manager)', 'File Explorer',
#        'File Manager',
#        'File Manager -- Take Command of Your Files Easily',
#        'Files Go by Google: Free up space on your phone',
#        'FilterGrid - Cam&Photo Editor', 'Filters for B Live',
#        'Filters for Selfie', 'Final Fantasy XV: A New Empire',
#        'Financial Times', 'Find Dining Restaurant Finder',
#        'Find Real Love — YouLove Premium Dating',
#        'Find a Way: Addictive Puzzle', 'Find&Save - Local Shopping',
#        'FindShip', 'Firefox Browser fast & private',
#        'Firefox Focus: The privacy browser', 'Fishdom', 'Fitbit',
#        'Fitbit Coach', 'Flashlight', 'Flashlight & LED Torch',
#        'Flashlight - Torch LED Light', 'Flashlight HD LED', 'Flickr',
#        'Flight & Hotel Booking App - ixigo',
#        'Flightradar24 Flight Tracker', 'Flights',
#        'Flip the Gun - Simulator Game', 'FlipaClip - Cartoon animation',
#        'Flipboard: News For Our Time', 'Flipkart Online Shopping App',
#        'Flipp - Weekly Shopping',
#        'Flippy Campus - Buy & sell on campus at a discount',
#        'FlirtChat - ♥Free Dating/Flirting App♥', 'Floor Plan Creator',
#        'Flow Free', 'Flowers Live Wallpaper', 'Fly Delta',
#        'FollowMyHealth®', 'Font Studio- Photo Texts Image',
#        'Food Calorie Calculator', 'Food Network',
#        'Fooducate Healthy Weight Loss & Calorie Counter',
#        'Foot Mercato : transferts, résultats, news, live',
#        'Football Live Scores', 'ForecaWeather',
#        'Fortune City - A Finance App', 'FotMob - Live Soccer Scores',
#        'Fotor Photo Editor - Photo Collage & Photo Effects',
#        'Four In A Line', 'Four In A Line Free', 'Foursquare City Guide',
#        'Foursquare Swarm: Check In', 'Fox Business',
#        'Fox News – Breaking News, Live Video & News Alerts',
#        'Fraction Calculator Plus Free', 'Free & Premium VPN - FinchVPN',
#        'Free Book Reader', 'Free Books - Spirit Fanfiction and Stories',
#        'Free Dating & Flirt Chat - Choice of Love',
#        'Free Dating App & Flirt Chat - Cheers',
#        'Free Dating App & Flirt Chat - Match with Singles',
#        'Free Dating App - Meet Local Singles - Flirt Chat',
#        'Free Dating App - YoCutie - Flirt, Chat & Meet',
#        'Free Dating Hook Up Messenger',
#        'Free Foreclosure Real Estate Search by USHUD.com',
#        'Free Hypnosis', 'Free Live Talk-Video Call',
#        'Free Meditation - Take a Break',
#        'Free Messages, Video, Chat,Text for Messenger Plus',
#        'Free Panda Radio Music', 'Free Sports TV',
#        'Free TV Shows App:News, TV Series, Episode, Movies',
#        'Free VIN Report for Used Cars', 'Free live weather on screen',
#        'Free phone calls, free texting SMS on free number',
#        'FreePrints – Free Photos Delivered',
#        'Freeletics: Personal Trainer & Fitness Workouts',
#        'Freeme Launcher—Stylish Theme', 'Fresh EBT - Food Stamp Balance',
#        'FreshBooks Classic', 'Frontback - Social Photos',
#        'Frozen Free Fall', 'Fruit Block - Puzzle Legend', 'Fruit Boom',
#        'Fruit Cube Blast', 'Fruit Ninja®', 'Fruits Bomb',
#        'Fuelio: Gas log & costs', 'Full Screen Caller ID',
#        'Fun Kid Racing', 'Fun Kid Racing - Motocross',
#        'Funny Alarm Clock Ringtones', 'Funny Pics', 'Funny Quotes Free',
#        'Funny Ringtones', 'Futbol24', 'Fuzzy Seasons: Animal Forest',
#        'G Cloud Backup', 'GANMA! - オリジナル漫画が全話無料で読み放題',
#        'GCash - Buy Load, Pay Bills, Send Money', 'GMAT Math Flashcards',
#        'GMAT Question Bank', 'GMX Mail',
#        'GO Keyboard - Cute Emojis, Themes and GIFs',
#        'GO Keyboard - Emoticon keyboard, Free Theme, GIF', 'GO Notifier',
#        'GO SMS Pro - Messenger, Free Themes, Emoji',
#        'GO Weather - Widget, Theme, Wallpaper, Efficient', 'GPS Map Free',
#        'GPS Navigation & Offline Maps Sygic',
#        'GPS Speedometer - Trip Meter - Altimeter',
#        'GPS Speedometer and Odometer', 'GPS Speedometer, Distance Meter',
#        'GPS Status & Toolbox',
#        'GPS Traffic Speedcam Route Planner by ViaMichelin',
#        'GRE Flashcards', 'GRE Prep & Practice by Magoosh', 'GRE Tutor',
#        'GS SHOP', 'GUNSHIP BATTLE: Helicopter 3D',
#        'Galactic Core Free Wallpaper', 'Galaxy Attack: Alien Shooter',
#        'Galaxy Gift', 'Galaxy Live Wallpaper',
#        "Game for KIDS: KIDS match'em", 'Game of Thrones: Conquest™',
#        'Gametime - Tickets to Sports, Concerts, Theater',
#        'Garden Coloring Book', 'Garden Fruit Legend',
#        'Garden Photo Frames - Garden Photo Editor', 'Gardenscapes',
#        'Garena Free Fire', 'Gay Sugar Daddy Dating & Hookup – Sudy Gay',
#        'Gboard - the Google Keyboard', 'Gems or jewels ?',
#        'Genius Scan - PDF Scanner', 'Geo Tracker - GPS tracker',
#        'Geocaching®', 'Geometry Dash World', 'Ghostery Privacy Browser',
#        'GialloZafferano: le Ricette', 'Girls Hairstyles',
#        'Girls Live Chat - Free Text & Video Chat',
#        'Girls Online Talk - Free Text and Video Chat', "Girls' Frontline",
#        'Girly Lock Screen Wallpaper with Quotes',
#        'Girly Wallpapers Backgrounds', 'Glam - Premium Dating App',
#        'GlassesOff', 'Glide - Video Chat Messenger', 'Glow Hockey',
#        'Glowing Flowers Live Wallpaper', 'Gmail', 'GoBank',
#        'GoPro (formerly Capture)',
#        'Goibibo - Flight Hotel Bus Car IRCTC Booking App',
#        'Goku Wallpaper Art', 'Gold Butterfly Keyboard Theme',
#        'Golden Dictionary (EN-AR)', 'Golden Launcher',
#        'Golf GPS Rangefinder: Golf Pad', 'GolfLogix GPS + Putt Breaks',
#        'GolfNow: Tee Time Deals at Golf Courses, Golf GPS',
#        'GoodRx Drug Prices and Coupons', 'Google', 'Google Ads',
#        'Google Allo', 'Google Analytics', 'Google Assistant',
#        'Google Assistant Go', 'Google Calendar',
#        'Google Chrome: Fast & Secure', 'Google Classroom', 'Google Docs',
#        'Google Drive', 'Google Duo - High Quality Video Calls',
#        'Google Earth', 'Google Handwriting Input', 'Google My Business',
#        'Google News', 'Google Pay', 'Google Photos', 'Google Play Books',
#        'Google Play Games', 'Google Play Movies & TV', 'Google Primer',
#        'Google Sheets', 'Google Slides', 'Google Street View',
#        'Google Translate', 'Google Trips - Travel Planner',
#        'Google Voice', 'Google+', 'Granny', 'Graphing Calculator',
#        'Grim Soul: Dark Fantasy Survival',
#        'Groovebook Photo Books & Gifts', 'GroupMe',
#        'Grubhub: Food Delivery', 'H TV', 'H&M',
#        'HBO GO: Stream with TV Package', 'HBO NOW: Stream TV & Movies',
#        'HD Camera', 'HD Camera - Best Cam with filters & panorama',
#        'HD Camera - Quick Snap Photo & Video',
#        'HD Camera Pro for Android', 'HD Camera Ultra',
#        'HD Camera for Android', 'HD Movie Video Player',
#        'HD Video Player', 'HD Widgets', 'HDFC Bank MobileBanking',
#        'HESI A2 Pocket Prep',
#        'HISTORY: Watch TV Show Full Episodes & Specials', 'HOTEL DEALS',
#        'HSL - Tickets, route planner and information', 'HTC Calendar',
#        'HTC File Manager', 'HTC Gallery', 'HTC Lock Screen',
#        'HTC Service － DLNA', 'HTC Social Plugin - Facebook', 'HTC Speak',
#        'HTC Weather', 'Hairstyles step by step',
#        'Hamilton — The Official App', 'Hangouts',
#        'Hangouts Dialer - Call Phones', 'Happify',
#        'Happy Birthday Songs Offline', 'Happy Fruits Bomb - Cube Blast',
#        'Happy Street', 'Harkins Theatres',
#        'Harry Potter: Hogwarts Mystery', 'HauteLook', 'Hay Day',
#        'Haystack TV: Local & World News - Free',
#        'Headspace: Meditation & Mindfulness',
#        'Health and Nutrition Guide', 'Healthy Recipes Free', 'Helix Jump',
#        'Hello Kitty Lunchbox', 'Hello Kitty Nail Salon', 'Hello Stars',
#        'HelloTalk — Chat, Speak & Learn Foreign Languages', 'Hemnet',
#        'Henry Danger Crime Warp', 'Hero Hunters',
#        'Herpes Dating: 1,000K+ Singles', 'Herpes Positive Singles Dating',
#        'Hide App, Private Dating, Safe Chat - PrivacyHider',
#        'Hide Something - Photo, Video', 'Hideman VPN',
#        'High Blood Pressure Symptoms', 'High-Powered Flashlight',
#        'High-Speed Camera (GIF,Burst)', 'Hill Climb Racing',
#        'Hill Climb Racing 2', 'Hily: Dating, Chat, Match, Meet & Hook up',
#        'Hinge: Dating & Relationships', 'HipChat - Chat Built for Teams',
#        'Hipmunk Hotels & Flights', 'Hitwe - meet people and chat',
#        'Hiya - Caller ID & Block', 'Hola Launcher- Theme,Wallpaper',
#        'Hole19: Golf GPS App, Rangefinder & Scorecard',
#        'Home Decor Showpiece Art making: Medium Difficulty',
#        'Home Scouting® MLS Mobile',
#        'Home Security Camera WardenCam - reuse old phones',
#        'Home Street – Home Design Game', 'Home Workout - No Equipment',
#        'Home Workout for Men - Bodybuilding',
#        'Home workouts - fat burning, abs, legs, arms,chest',
#        'HomeAway Vacation Rentals', 'HomeWork',
#        'Homes.com 🏠 For Sale, Rent', 'Homescapes',
#        'Homesnap Real Estate & Rentals',
#        'Homestyler Interior Design & Decorating Ideas',
#        'Homework Planner', 'Honkai Impact 3rd',
#        'Hopper - Watch & Book Flights',
#        'Horoscopes – Daily Zodiac Horoscope and Astrology',
#        'Horses Live Wallpaper',
#        'Hostelworld: Hostels & Cheap Hotels Travel App',
#        'Hot Wheels: Race Off', 'Hot or Not - Find someone right now',
#        'HotelTonight: Book amazing deals at great hotels',
#        'Hotels Combined - Cheap deals',
#        'Hotels.com: Book Hotel Rooms & Find Vacation Deals',
#        'Hotspot Shield Free VPN Proxy & Wi-Fi Security', 'Hotstar',
#        'Hotwire Hotel & Car Rental App', 'Housing-Real Estate & Property',
#        'Houzz Interior Design Ideas'], dtype=object)

# %% [markdown]
# *The above displays the unique Apps for which there are missing values in **Reviews** column*

# %%
'''
def apps_missing_reviews(dataset):
    for values in dataset['App'].unique().tolist():
        if dataset[dataset['App']==values].App.count() != dataset[dataset['App']==values].Reviews.count():
            print(values, " : ", dataset[dataset['App']==values].App.count(), " : ", dataset[dataset['App']==values].Reviews.count())
            
apps_missing_reviews(df)
'''
# Out:
# '\ndef apps_missing_reviews(dataset):\n    for values in dataset[\'App\'].unique().tolist():\n        if dataset[dataset[\'App\']==values].App.count() != dataset[dataset[\'App\']==values].Reviews.count():\n            print(values, " : ", dataset[dataset[\'App\']==values].App.count(), " : ", dataset[dataset[\'App\']==values].Reviews.count())\n            \napps_missing_reviews(df)\n'

# %% [markdown]
# *The above displays the Apps for which there are 1 or more missing values in the **Reviews** column*

# %%
'''
def apps_no_missing_reviews(dataset):
    for values in dataset['App'].unique().tolist():
        #print(values)
        if dataset[dataset['App']==values].App.count() == dataset[dataset['App']==values].Reviews.count():
            print(values, " : ", dataset[dataset['App']==values].App.count(), " : ", dataset[dataset['App']==values].Reviews.count())
            
apps_no_missing_reviews(df)
'''
# Out:
# '\ndef apps_no_missing_reviews(dataset):\n    for values in dataset[\'App\'].unique().tolist():\n        #print(values)\n        if dataset[dataset[\'App\']==values].App.count() == dataset[dataset[\'App\']==values].Reviews.count():\n            print(values, " : ", dataset[dataset[\'App\']==values].App.count(), " : ", dataset[dataset[\'App\']==values].Reviews.count())\n            \napps_no_missing_reviews(df)\n'

# %% [markdown]
# *The above displays the Apps for which there are no missing values in the **Reviews** column*

# %% [markdown]
# #### Dropping rows having missing values in the Reviews column

# %%
df = df[df['Reviews'].isnull()==False]

# %%
df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                                  Reviews Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# 64222  Most ads older many agents ..not much owner po...  Positive
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 3                0.400000                0.875000
# 4                1.000000                0.300000
# 5                1.000000                0.300000
# ...                   ...                     ...
# 64222            0.173333                0.486667
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000
#
# [29692 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# App                       0
# Reviews                   0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %% [markdown]
# *There are no more missing values in the dataset*

# %%
df.to_csv('file1.csv', index=False)

# %%
df = pd.read_csv('file1.csv')

# %%
df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 29687  Housing-Real Estate & Property
# 29688  Housing-Real Estate & Property
# 29689  Housing-Real Estate & Property
# 29690  Housing-Real Estate & Property
# 29691  Housing-Real Estate & Property
#
#                                                  Reviews Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2             Works great especially going grocery store  Positive
# 3                                           Best idea us  Positive
# 4                                               Best way  Positive
# ...                                                  ...       ...
# 29687  Most ads older many agents ..not much owner po...  Positive
# 29688  If photos posted portal load, fit purpose. I'm...  Positive
# 29689  Dumb app, I wanted post property rent give opt...  Negative
# 29690  I property business got link SMS happy perform...  Positive
# 29691  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                0.400000                0.875000
# 3                1.000000                0.300000
# 4                1.000000                0.300000
# ...                   ...                     ...
# 29687            0.173333                0.486667
# 29688            0.225000                0.447222
# 29689           -0.287500                0.250000
# 29690            0.800000                1.000000
# 29691           -0.316667                0.400000
#
# [29692 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# App                       0
# Reviews                   0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %% [markdown]
# #### Cleaning the punctuation marks

# %%
import re
import string

# %%
#df['Reviews'].unique().tolist()

# %%
def remove_punctuation(text):
    no_punct = "".join([c for c in text if c not in string.punctuation])
    return no_punct
    
df['Reviews'] = df['Reviews'].apply(lambda x: remove_punctuation(x))

# %%
def cleaning(dataset, characters):
    dataset['Reviews'] = dataset['Reviews'].str.lower()
    dataset['Reviews'] = dataset['Reviews'].str.replace('*', 'i')
    dataset['Reviews'] = [re.sub('♥️|❤|\d', '', e) for e in df['Reviews']]
    dataset['Reviews'] = [re.sub('\s+', ' ', e) for e in df['Reviews']]
    for ch in characters:
        dataset['Reviews'] = dataset['Reviews'].str.replace(ch, '')
    return dataset
        
        
        
char=['☆', '✌', '—']
df = cleaning(df, char)

# %%
df.Reviews.unique().tolist()
# Out:
# ['i like eat delicious food thats im cooking food myself case best foods helps lot also best before shelf life',
#  'this help eating healthy exercise regular basis',
#  'works great especially going grocery store',
#  'best idea us',
#  'best way',
#  'amazing',
#  'looking forward app',
#  'it helpful site it help foods get ',
#  'good you',
#  'useful information the amount spelling errors questions validity information shared once fixed stars given',
#  'thank you great app add arthritis eyes immunity kidneyliver detox foods please ',
#  'greatest ever completely awesome maintain health this must ppl there love it',
#  'good health good health first priority',
#  'health its important world either life think ',
#  'mrs sunita bhati i thankful developersto make kind app really good healthy food body',
#  'very useful in diabetes age i need control sugar thanks',
#  'one greatest apps',
#  'good nice',
#  'healthy really helped',
#  'god health',
#  'health should always be top priority on mysg',
#  'an excellent a useful',
#  'i found lot wealth form health',
#  'because i found important',
#  'healthy eating',
#  'very good simply good',
#  'on test',
#  'good',
#  'thanks advice downloaded adobe reader still cant get recipe book',
#  'no recipe book unable recipe book',
#  'absolutely fabulous phenomenal',
#  'great love food',
#  'excellent it really works',
#  'best',
#  'wealth of information very informative easy understand the ads middle page interupted read update my ad comment not objection ads literally position ads smack dab middle i new spartphones apps didnt know not click eveything i saw but full review',
#  'not description good',
#  'great app love',
#  'loved very helpful',
#  'good healthy foods',
#  'waste time it needs internet time n ask calls information',
#  'best thing i lost ten lbs two months help tips',
#  'ten best food promote good health good health essential long healthy lifestyle make habit eat foods promote good health eat fruits veggies every day',
#  'healthy food really good information eat healthy',
#  'my mom dad important thing this good share',
#  'a big thanks ds i got bst gd health',
#  'lovely best everyone needs',
#  'love it i lost pounds far ',
#  'i like',
#  'thanks helpful app',
#  'good food really good eat',
#  'thanks thank u much',
#  'love this really good',
#  'this helpful',
#  'i love',
#  'very useful',
#  'great love',
#  'very informative',
#  'luv',
#  'great',
#  'wonderful',
#  'doesnt work zero',
#  'weight loss not bad',
#  ' best foods u excellent chose foods',
#  'this needed most',
#  'faltu plz waste ur time',
#  'best food thank you recipe book',
#  'i love good',
#  'i like superb',
#  'good v good',
#  'healthy',
#  'quick read',
#  'great ideas',
#  'too good',
#  'cool',
#  'best best',
#  'great great',
#  'food list easy i predibetic i scared all dr said potatoes rice bread he never told i could eat i supplied paperwork stating things could happen me this tells get works thank calming downawesome app get it',
#  'great wife my wife enjoy much shes kinda person like follow health diet shes spending much time front pc find appropriate diet food her now found magnificent app thank you thumbs up',
#  'great very interesting useful application i like it',
#  'crap doesnt work',
#  'this starr download',
#  'i like was helpful',
#  'nice super get',
#  'nice nice collection',
#  'wow',
#  'interesting it interesting info i think worth storage space phone id rather research computer print list neat idea make life easier provide entertainment i expect app',
#  'luv it simple easy understand well thought i follow step step problems see results i also luv apps gives food choices but looks like foundation keep good work',
#  'not good its good u net connection u cant play appso much good',
#  'awesome resources i begin new journey i cant see great results',
#  'boring i thought actually just texts thats it too poor old texts',
#  'love app it gives way good idea i buying store eating daily basis',
#  'great its really best unique provides detailed information food nutritious staying healthy hats developer giving free',
#  'nothing special could find anything useful',
#  'its ok i love ok',
#  'nice',
#  'almost mobile phone',
#  'very effective efficient convenient find available jobs keep good work power job search',
#  'easy intuitive',
#  'good searching job internship',
#  'not bad price little bit expensive',
#  'easy use',
#  'job search results ios eg security',
#  'easy',
#  'well it is also the largest human bank in taiwan can you please app ui',
#  'so',
#  'helpful',
#  'very good job hunt',
#  'easy to use',
#  'good find job easily',
#  'good meet good',
#  'awesomeee',
#  'why english version',
#  'the operation interface information content is richer than and it is also better to useutility without flashing back',
#  'is the development method completed in the early days the computer web version and the mobile app the function seems to be short or not the same in the same function page for example the similar work function of similar companies is not in the app version',
#  'this better suited possibly somebody understands pitfalls modern technology',
#  'useful handy terminal mobile devices uiux improved ',
#  ' job hunt so amazing easy use thanx guys',
#  'convenient easy using many large corporation it',
#  'easy to use interface',
#  'easy simple easy use',
#  'easy found job',
#  'useful this useful chinese difficult peoples read chinese if add english language useful',
#  'selling a phone number after completing the resume for minutes i was hit by my mobile phones including nanshan life insurance',
#  'very helpful very easy userfriendly brilliant app',
#  'good very helpful',
#  'very good very convenient easy to use very beautiful very good',
#  'ok',
#  'horrible id verification',
#  'easy even basic korean searching english usually bring results products shipped overseas best search korean',
#  'i do not collect it for a month but i will not refund it he said he would only call me all month',
#  'top bar missing newest update hard shop cant search',
#  'there is nothing missing ',
#  'refund takes long days still received money crazy',
#  'i enjoying online shopping via st app perfect',
#  'good enough',
#  'i switching gmarket twice sts new face',
#  'forced full screen popups',
#  'is it sound like you want to clear chrome and pay for it again because android users can not pay for chrome error i have to fix the app is it really true its makgeolli',
#  'i am trying to update every time but i do not stall its still difficult to search and im tired of seeing categories by category the benefits are getting less and less',
#  'just try so far good',
#  'icon name is strange after updating',
#  'comskplanetsyruppaycardrecognizedlib',
#  'best shop',
#  'i forgot password cant get new',
#  'force update',
#  'she',
#  'love nature',
#  'language barrier i understand korea i want english',
#  'shipping view flexible view make it right why do not you come out ',
#  ' points i want to give no points shortage i clicked on the internet address i could not find the product i popped up and the th avenue app was automatically turned on and it was automatically abducted so i can not use the internet app',
#  'five star its nice',
#  'forced termination is too severe if you try to view detailed information it will be forcibly terminated',
#  'open market revolution a section of the heloship open market mobile service there are still many page areas that can not be served by mobile service and the interface is also an urgent level for page loading if you understand that there is a limit to the source control of the product information provided by the sellers it is a chronic problem that problems arise in the loading of coupons or on the benefit management page',
#  'english version hi possible english version thank you',
#  'if you have a phone that is authenticated by otp and you call the agent you will be able to find it there is a letter authentication and there is also an email if you do not do such a thing and call a counselor',
#  'it has been slowed down since the last update its hard for me to pay for the product ill give up when im alive',
#  'good good',
#  'if a network error occurs the app should save the state and try again or try to repoint the next time but thats it and its gone its totally tough',
#  'problem language i dont understand language used app i advise keep option user choose language may prefer',
#  'nice so nice apps',
#  'dont english language like',
#  'great hassle free way order contacts got call reminding prescription expires tomorrow',
#  'its expensive i expected i thought id saving money cutting middle man waaaaay convenient doctors office',
#  'super fast navigation brand fasteasy checkout additional ads bs',
#  'easy step step process correct information took minutes place order',
#  'placing order easy especially paper copy rx ill update review i receive order rebate',
#  'super fast ordering reordering easy interface love convenience app',
#  'i love makes getting contacts easy',
#  'easy use will def recommend',
#  'love app super easy use ordered contacts less minute',
#  'this easy use ordering process fast efficient',
#  'so simple cave man it',
#  'simple fast easy use no eye appointments',
#  'very user friendly',
#  'very easy use love free shipping',
#  'very easy use',
#  'dope',
#  'easy affordable',
#  'so easy app made ordering contacts breeze great prices too',
#  'does need do no sense giving anything less stars',
#  'worked well glad i',
#  'its hell lot easier i thought it would be',
#  'it made getting new contacts easy',
#  'i love app so easy super convenient',
#  'hopefully work well first time user',
#  'contacts shipped time efficient',
#  'very easy',
#  'easy access',
#  'first time app always used doctors office stand behind tore contacts hoping solve problem contacts',
#  'months later gs still notify expired lenses useless lens notifications work successfully pushes alerts discounts the fundamental reason keep running lens expiration notification work my notification settings fine',
#  'good prices exceptional customer service order sent particular fault begin thoroughly checking information completing order when i emailed i got response rather quickly hours correction made i receiving free overnight shipping ensure getting lenses promptly wonderful',
#  'its quick easy order contacts app i love it and really saves time money makes extremely happy got love free market capitalism',
#  'ordered sunday got call verifying last name recently married scheduled shipped monday happy customer',
#  'took seconds find rx get contacts ordered convenient',
#  'short simple sweet super easy took less mins order contacts plus savings',
#  'super easy not super cheap cheaper actually going optometrist good deals shipping',
#  'very useful streamlines eye care needs recommend contact wearers very reliable shipping easy well',
#  'very easy use they remembered last order i figure out',
#  'this well designed easy convenient',
#  'gets theres ad every single level restart frustrating potential',
#  'the game interesting challenging however often buffers gets stuck',
#  'wow i play puzzle st round i remember puzzle solve childhood lovely',
#  'love game deleting ive waiting months levels play i several updates none updates added new levels',
#  'way many aggressive ads',
#  'amaze im addicted',
#  'i like game',
#  'i play game',
#  'its toooo gud game',
#  'too many unskippable ads other than great game',
#  'mind uses game',
#  'too much ad',
#  'it great experience knowledge help game',
#  'nice game',
#  'i really good game',
#  'i love game nice',
#  'it granite',
#  'it confusing',
#  'its really fun',
#  'is game beautiful',
#  'guide',
#  'super',
#  'yoko',
#  'its great',
#  'very nice',
#  'its cool',
#  'fantastic',
#  'superb',
#  'excellent',
#  'love',
#  'fun',
#  'enjoy',
#  'love ',
#  'good graphics ok way many ads ridiculous cant skip them tbh waste timewould not recommend',
#  'terrible amount ads covering content making unpleasant play avoid',
#  'like the old version better where backspace is beside p letter and emoji is below capitalization',
#  'i like far',
#  'its really useful i really like',
#  'i cant send emojis without saying change input i know change input',
#  'bullsht when open apps says sill never register personal data credit card number once go activate de setting message pops say personal data credit data enregistrate hahha thats bullsht',
#  'easy use best keyboard useful',
#  'fuzzy',
#  'perfect',
#  'awesome',
#  'this good keyboard emoji users sensitive constant nags change themes which cant disabled block top screen extremely irritating',
#  'last update bugi cant open keyboard setting always fc im back old version',
#  'works fine no need update',
#  'you are here',
#  'i hate',
#  'meh yeah',
#  'amazing app',
#  'good emoji keyboard',
#  'its lit',
#  'love it',
#  'loved',
#  'the best emoji keyboard ever in love',
#  'after update emoji cant used normally',
#  'best keyboard never freezes like keyboard ive used ive never problems using think deserves stars ⭐⭐⭐⭐⭐',
#  'this really good go get ehh',
#  'terrible not userfriendly like original app please give customers option both i look forward navigating cumbersome app namaste',
#  'deeply disappointed my free days longer works it asking high price meditations i expect oprah involved scam i respect her',
#  'update looks good would without added pictures purchasing products taking space phone all products already available making pictures redundant thanks experience',
#  'i guess cant please everyone i loved update im sure idea streamlined is cant even read full title meditation trying use theres problem i love meditations themselves comparing update update the quality functionality like comparing apples oranges opinion im sure looking wanted changes feels completely mark',
#  'this good ever i get notification phone stops meditation playing annoying i press play disturbs meditation i prefer ed upgrade',
#  'i able listen days past frozen crashed play i liked upgrade point lot',
#  'love offers dislike intensely keeps playing episode episode hours end used stop selected finished much better way',
#  'seems like update occurred let access free meditation experience yesterday did today matter try let me frustrating',
#  'im days free meditation attraction at first i could see program free but update keeps showing order continue i pay',
#  'i started manifesting i want from nd day my meditation i wholeheartedly thank deepak ji oprah bringing this excellent app highly recommend it',
#  'great experience user friendly navigation',
#  'it would best crashing time the new version keeps crashing every time i open app im missing day experiences ones i purchased i cannot access now its getting frustrating plus new version allow view daily meditation full review',
#  'the day meditations excellent addition daily meditation practice truly enjoy listening oprah deepak short enough anytime am pm it would merit star ongoing glitch ive uninstalled reinstalled fixed it when full review',
#  'this glitchy phone more often not itll say mediation failed load available ive deleted reinstalled several times nothing seemed work frustrating',
#  'i love meditation sessions especially i love try meditation commit buying it and great customer service there couple reasons i give stars they stopped supporting older os smartphones lower end me full review',
#  'frozen day things w were moving along great i hit day stuck therenow everyday returns back daywhat waste time new year same problem freezes minutes playing anything calming transformative experience',
#  'stressed i downloaded start time i got emails saying day expired within days i already missed day i needed day day meditation individuals time frame and i want pay deep thinker full review',
#  'update apr i love itl reliable consistent old review lately every night i shows unable library message i uninstal n reinstall nightly contacted support team told work so bad ',
#  'great meditations two things i wish would improve on allow daily reminders items purchased library set time daily reminder writing journal blank space scrolls it would nice instructions scroll well bc much r full review',
#  'this totally awesome little trouble times w wanted go back relisten rewind recording freaked close start',
#  'day fine but day froze quarter way thru meditation thats disruptive id rather online version uninstalling',
#  'overall easy use houses meditation programs i purchased place allows stream time makes participating day programs breeze gave four stars hang becomes stuck sometimes',
#  'regular free meditations whats love they like spiritual teaching meditation ive even bought quite few great value',
#  'i enjoy using complete meditations anywhere however day meditation series allow journaling way online via desktop this huge faux pas strongly important part experience',
#  'i problems reviewers mentioned this working great i love hearing oprah deepaks voiceso calming its great addition regular practice',
#  'love music voices i like i access all meditations days i missed trip i cant access them',
#  'best apphands down i love variety sample meditations choose from that mediation intro read prepare whats come this duo dynamic oprah deepak force reckoned withthank helping become best sel full review',
#  'the content great hard use gives sense actions progressing seems outdated poorly made the easier need updating its shame program good',
#  'it extremely calming excellent method center day it brings anxiety stress levels leading progressive peaceful energetic positive mindset i highy recommended hard time reaching true desired level full review',
#  'has paid library available plus lists free meditation offer easy keep track navigate does always allow listen downloaded meditations i internet the free experience registers i get reminders ive missed experience thanks fix',
#  'love access meditations after playing day though jumps back days starts replaying can fix glitch',
#  'i know begin i asked whatever want call life force i received answers i imagine incredible positive creative flow meditations generate join together july the unified field within us full review',
#  'this good i updated it now i cannot access journal entries it says journal available meditation every day please fix',
#  'i love app quick easy use right size read im able meditate anywhere wo laptop i dont access email meditation experience i handy app i love day experience i get time thanks much',
#  'i love and depend app in which journal would stay days access free meditationsstill made significant positive impact life',
#  'nice work consistently had frequent glitches barring access journal parts content',
#  'thank changing permissions access when i done meditation i enjoy quietthis auto plays another right away makes awful loud introduction next meditation this happened night uses data i catch it please consider changing i rea full review',
#  'amazing meditation sessions only wish option keep expired currently shredding weight oprah absolutely helping stay track keep accountable',
#  'ive meditating oprah deepak using day meditation experience several years now occasionally topics practice resonated enough ive bought again i look forward new day experience enthusiasm excitement they gui full review',
#  'simple easy use unnecessarily wastes time a good investment time personal growth',
#  'this good dating app i love much this lot chinese english speaking members most active i chat requests soon registered there advertising i chat others members freely i used different dating apps functions simple direct one users exchanged contact easily those guys met nice gentle serious feeling good it hopefully every enjoy using app',
#  'thank friend introduced dating me this changed impression dating app this first time real date real life dating app i happy that im satisfied quality app especially excellent customer services functions user oriented localized users active i wait long users replies matching finally i honestly give big like app hope enjoy app',
#  'this seems nice need vip even send message another party this issue users wish pay membership time being its understandable cant send msg first party msg you able reply without problem',
#  'dont waste money become vip tons there this scam rubbish',
#  'fung app just wasting time you send receive heart signs cant send receive messages asking money messages better find another platform',
#  'i like dating much different dating apps members truly want make friends the personal information users good detail helps easily understand members functions interfaces dating simple user friendly advertisement it easy get start find someone chat directly users active serious i met member similar interests values we dinning offline sometimes joined activities others i hope everyone make friends i find half ',
#  'am happy here its interesting hello friends i glad meet u all lets enjoy',
#  'well actually good but thing allowed match day and plus filters country u want socialize it happen randomly chosen',
#  'niceit many gals users friendly good dating app much better others',
#  'nice it attractive function members friendly best choice meet new friends',
#  'nice it attractive functions users nice feeling good it',
#  'niceit many function the best meet friend',
#  'you cant chat girls without paying premium waste time',
#  'chatting behind paywall youre unable initiate conversations anyone without paying subscription fee',
#  'its hard send message likes meits also worst site needs vip member send message',
#  'nice it many gals users friendly its great easy use',
#  'nice also users much friendly love',
#  'if dont want spend money dating dont it need make payment become vip chat others',
#  'why cant reply message',
#  'a good way start something different',
#  'just nice sote focus wanted',
#  'nice it alot users',
#  'nice many people inside',
#  'we cant even send messages anyone unless vip memberits purely business',
#  'cant receive email and cant reply message',
#  'this app is worthy of praise but still needs to work hard',
#  'it’s so cool it’s hard to use it it’s hard for you',
#  'nice many members i like it',
#  'not good even simplest messages function needs vip',
#  'does necassary vip members sent message others',
#  'lots fake account',
#  'really worth a try dating platform good quality ',
#  'nice app people friendly like it',
#  'nice many members users active its great easy use',
#  'its ok easy access',
#  'vosan wong',
#  'nice it many gals users friendly well designed easy ',
#  'this perfect',
#  'thanks lot excellent map gis i love it like much its working well even without data connection thats helpful people go ahead keep us',
#  'the application very much helps out when there is no connection to wifi in addition the route is total transport in the city is a huge plus',
#  'very good app you get lost anywhere',
#  'not showing easily fastest routes united arab emirates taking longitudes latitudes map coordination inputs every location uae united arab emirates need update maps latest d updated street name area location poi restaurant hotels atm',
#  'it useful find offices places uae love offline facility',
#  'love cause always gives date information really useful',
#  'a lot of intrusive advertising and suggestions invitations become an agent or a photographer',
#  'i ask to add the opportunity to watch where some buses are currently online that is displayed as in yandex transport',
#  'increase the launch speed on weak devices',
#  'need improve lot location search suggestions',
#  'i like map show abu dhabi i want add abu dhabi also possible',
#  'previously the application was eating less battery now the consumption is estimated by the phone as high intensive',
#  'i moved to another city without knowing the areas everywhere this application helps out',
#  'making life easy thanks lot gis',
#  'its useful its helping always find location',
#  'nothing',
#  'i wish maps countries around world',
#  'already a couple of weeks is very buggy what happened then everything happens slowly with delay or even hang',
#  'a good application but you need to work with updates for example an object is built but you do not have it there',
#  'the really good offline navigation iam visit visa dubai helped lot navigation searching jobs as feedback would like developers knows developmental activities routes changed also stops changed please update it',
#  'i think itd great u add notifications app ex theres onetwo busstops till destination point people could leave open without checking watching way again like i it little paranoid scared miss stop',
#  'the application is very healthy but i do not know how much the application has started to hang constantly and fly out very often a white screen just appears and the application hangs',
#  'everything was fine then for some reason you stopped updating the maps for example at the exhibition of economic achievements for a long time there is a repair and postponed the transfer i was hoping that the july update will fix but no nothing happened',
#  'yesterday tooks wrong location going meeting meeting got canceled delay reach right place in al quoz dubai',
#  'thank app i often different cities i go please add tashkent city this capital uzbakistant',
#  'this good people send whats working plz check',
#  'awesommmmmmmmmm app jst dwnld nd njy we nt get trapped anywhr pakka',
#  'i always use the application i think that the most convenient interface from all offline maps but was very surprised that i did not find in the list of cities in minsk i had to download the competitor application',
#  'best i have ever used in offline mode it works very well in offline mode in uae',
#  'constantly flies it is impossible to use samsung galaxy note ',
#  'amazing please add multiple destinations',
#  'cool prog not just rescued',
#  'for pedestrians especially in a foreign city i do not know the application better but when you sit behind the wheel the impression spoils it is still convenient to find places in it but do not go to them repeatedly the navigator offered me to roll up or turn around so i would be on the roadway of oncoming traffic not to mention the fact that the navigator sometimes offers dirt roads instead of normal ones i spent the whole night at the track this winter',
#  'disgusting at first everything was fine but then i do not know what it is the language does not turn to say applications pereklinilo but i was offered twice the exact opposite route very much i do not advise it to download but if you dare be ready instead of the right place to go to the ebony sure that you are going right',
#  'best map dubai sharjah ajman please add abu dhabi rasalkhaima fujairah umm al qwain',
#  'its useful without internet',
#  'number aps world',
#  'always helps',
#  'amazing but also need location abu dhabi plzzzzz',
#  'for the icon thank you',
#  'what waiting for join platform thank later',
#  'kinda good know i find ms right',
#  'exciting experience meet someone dont idea of',
#  'best dating ever',
#  'very good',
#  'good app could free features like translation search engine settings',
#  'let try first',
#  'cant chat',
#  'just new',
#  'i really like could help find future chinese husband i really want name black woman really cool get find chinese house i find chinese guys attractive i need better looking japanese guys cuz japanese guys got flat faces',
#  'great loving',
#  'good fun',
#  'simple',
#  'its really great app i found girlfriend using redbeans my life much better pretty cute fits requirements could imagine life us redbeans highly recommended',
#  'i hate takes requirements send message',
#  'this ladies find partner when men try make friends ladies lady reply chat',
#  'amazing app easy intuitive found half redbeans highly recommend',
#  'its good full real people',
#  'is hard',
#  'nice g',
#  'nice app definitely need pay benefit it is way filter cities see whos nearby like website',
#  'ad said free chat',
#  'hope wish come true',
#  'sweet',
#  'rubbish',
#  'thief',
#  'it good way know many new friends i friend also this pay explored new world ',
#  'its really good i problem when make groupchats tells whole groupchat your email used second line create chat send messages groupchat actul message says email i would like fixed please other that amazing',
#  'everyday someone keeps calling me kinda bugs me every night ive send guys email every detail freakin mysterious call hope hear good news you',
#  'thanks fixing notification problem new recent update i give stars cause i miss calls texts anymore',
#  'when get phone calls make makes person line',
#  'whenever number verification say cannot plzz tell',
#  'it ring phone',
#  'this aap awesome',
#  'eight',
#  'i really liked features it really send receive sms calls wifi g however i queries developer why im able number whatsapp facebook registration why i able call us based landline numbers rest good far thanks ton',
#  'i loved ads starting popping using it get rid ads dominating entire screen i hate that at least put ads corners make small really hinder well i app',
#  'im using premium still poor quality calls voice breaks badly sometimes people cant even understand i tell them g wifi connection poorly designed',
#  'i cant even it i deleted first i downloaded cos even letting register i cant again please need work app',
#  'my calls keep dropping complete this sucks trying take care important calls handle business may able reach person need talk to',
#  'cant create account keeps saying an error occurred tried different emails different passwords nothing',
#  'cant create account tried different emails says an error occurred wasted time uninstalling',
#  'this keep dropping i open n loses signal takes long load friends receiving photos im sending them',
#  'keeps crashing keeps ending calls please fix on note ',
#  'fix problem the error occurred im happy give five stars',
#  'i installed signed upbut i able make calls texting receive send toany numbersi tried also canada numbers response',
#  'i really like app but i want know available iphone ',
#  'i cannot create account always pop connect error occurred',
#  'i pay credit make international calls never recieve it',
#  'it acts weird sometimes frustrating i need good line connect peoples with',
#  'this showing error signup',
#  'allow sign up fix problem',
#  'unable sing up always show error',
#  'as error occurred bata raha hai',
#  'i cant create accountit saying error occurred',
#  'sweet i original number i call text friends family',
#  'when creating account always showing error occurred ',
#  'its good creating number it shows error occurred plz fix',
#  'error occurred sign',
#  'remove add sign sure',
#  'great app you made great i enjoying it i love nd line',
#  'errorwhat heck',
#  'unable create account',
#  'always error',
#  'its great app easy works well',
#  'very nice easy',
#  'good business line now make wifi compatible',
#  'itd great u added exercises i mean chest back shoulders',
#  'some times exercises match designated body parts aim work on but still great all',
#  'helped get ideal body i wanted',
#  'always challenging definetly worth it i feel energetic loose day made better power too it puts little ease tells almost gives good advice',
#  'very challenging best workout far love',
#  'im disappointed confusing im able understanding level beginner intermediate advance exercise audio also working well workout full body workout content available full body workout accurate way something satisfaction',
#  'really good shows workout moves',
#  'have fun brother make a lot of fun thanks',
#  'great personal training',
#  'very helpful',
#  'ive tried multiple workout i seem always come back one the workouts categorized gives much break need workouts also rest day i really liked starts easy progresses days go by it also connects google fit ',
#  'i started i find motivation go gym i found days good way keeping gave lot motivation something i usually struggle with i calorie controlled diet because i cant give chocolate months i lost stone i started medium silver complete hard silver i side plank seconds started hold seconds not sure i go i certainly improved thanks app',
#  'i really enjoy app i love workout options the workouts get challenging progress i feel getting stronger i wanted pay app i saw reviews year stating free version options i would like buy ill wait ensure bugs fixed first',
#  'can please tell me i really confused how weight loss should follow easy medium hard levels daily complete monthly',
#  'this good gym instructorit covers home exercisesvery easily effectivelyif left exercises days remind come backit provide exercise may look effect weeksi love appi thankful designerthanks much',
#  'its easy use perfect people looking workout home you make easy hard want do category make longer workout like',
#  'love this its simple effective week easy program ive lost inches waist ive recommended friends family i even got husband workouts',
#  'i getting anywhere weight loss goalbut husband introduced app i achieved easily every amazed transformation',
#  'great app helps keep track workouts gives tips exercises workouts short get tired lot ads',
#  'just starting work slow i back injury great work pace',
#  'great app keeps motivated love day challenge end sight even days again',
#  'quick easy way work without go gym',
#  'i hate forces exercise everyday',
#  'help lot losing weight ive using since early july currently losing kg hee pray keep losing weight',
#  'i really love i like actually shows it',
#  'there many ads apart workouts really effective by th day noticeable changes seen',
#  'this helped get back great shape i often get complements toned i look',
#  'like workouts just wish variety workouts',
#  'great app easy great combination exercises keeps things interesting',
#  'it diet chart also it helpful us according everyones need diet also necessary',
#  'the amazing highlights within may post i downloaded see highlights otherwise i like listen i hope guys would i suggest idea may allow users post highlights match well i hope would look thanks',
#  'can log google many ads iritating please remove ads fix log problem',
#  'please update player list liga indonesia',
#  'great issues sorted',
#  'its amazing need new design',
#  'please add playbyplay scores especially mlb',
#  'very wonderful application',
#  'its best working ive used',
#  'i live colorado springs colorado need i say',
#  'better brainless runners actually makes think',
#  'it cool game i liked much helps developing concentration',
#  'excellent really tough higher cpu levels',
#  'its great game keep u busy hours obviously u know play',
#  'simple game pass time away my grandson like it',
#  'great way waist time',
#  'connect four v good',
#  'boring all put chip hole lets win',
#  'super fun game really good brain game',
#  'its boring this game sooooo boring ',
#  'could made better improving manoeuvre',
#  'addictive ive playing almost every day years a great version ',
#  ' row who knew row could fun',
#  'keeps busy',
#  'love ♥this game rocks ♥',
#  'nice simple game',
#  'ive played level three times them then i programmed ai c i let go second level fifteen times all i could make suggestion improving evaluation function like it uses concept zugzwang accurate',
#  'nice wallpapers theyre not k even k theyre presented theyre hardly fullhd thats perhaps scaled k making look grainy blurry would recommend phone screen resolution higher full hd nice collection great quality unfortunately',
#  'the refresh function scrambles excisting wallpapers who fooling lot wallpapers bad quality don‘t waste time',
#  'awesome app wallpapers vibrant exclusive mostly but excessive ads make miserable wallpapers please least reduce them',
#  'would better add animated wallpapers overall good daily updated wallpapers',
#  'this true k wallpapers great variety new wallpapers must added frequently',
#  'its good better k pictures',
#  'superb love wallpapers give confidence whenever look',
#  'this really cool amazing graphics is really enjoyable scroll threw look',
#  'gd bad',
#  'this good searching house',
#  'this app is basically a landlordseller oriented and the design is very user friendly it is not easy for the tenant to search it is filled with a bunch of advertisements for the fake landlord or agent 喔 for advertising it may be the main source of income for so it will be designed so that the tenantbuyer is not easy to search for a house because this company does not care about the tenants’ lives because they want advertising revenue so no will consider the convenience of use and search so it is strongly not recommended to use this app to search for a house',
#  'i have given examples what else is unclear are you not making money what is the debug users help would you like to send me a case  search and screening can be a little more rotten to find the result of the team can be screened and not screened for example searching taichung city in a map mode independent suites screening can open fire have a balcony and find a bunch of nonconforming conditions',
#  'map mode can see the number of objects and the approximate location but you cant click to view the pages of each object i will trouble you again thank you moto z play android ',
#  'it is also the telephone information but also to set up how to become so troublesome is it necessary for us not to download and use this app',
#  'rotten pushing the broadcast has been pushed rotten',
#  'need phone permission no way',
#  'no english such shame',
#  'personal collection cant synchronize with the web version the same account is added to the collection on the computer after the app is logged in none of them are synchronized',
#  'essential this essential foreigners living taiwan sure english version created simple translate app i speak mandarin would almost impossible read fine lines please get work',
#  'app cant post top let',
#  'what guys tencent theres folder called tencenttpush installed root directory internal storage updated latest version the log directory show receiving pushed contents comtencentandriodtpushactionsdk your shows taiwan company guys tencent i trust chinese company all i choice uninstall app',
#  'language is english option',
#  'please fix the update the house information can not be seen in the rental house',
#  'request english version please',
#  ' look filtering criteria better store filtering criteria future',
#  'too many ads',
#  '搵楼租楼 a lot of time a lot of time management easy to take care of',
#  'still rooms improve',
#  'i turned notification still keeping post',
#  'locations correct',
#  'not friendly english speaker only english interface apply contents not suitable english speaker',
#  'really helpful app',
#  'so far i like it the options talk get help connect great however qite bugs glitches im sure upgrade would offer wouldnt consider bugs worked out this great idea could help many people please fix bugs',
#  'its really awesome app when i problems i always talk people make feel better thank you',
#  'yeah cups fine glitchy sometimes less features available',
#  'quick honest response',
#  'i huge issue called listeners these people idea going about spread misinformation mental health lack empathy never reply when i politely told listener unhelpful told therapy useless joked blocked me i seriously hope people never go advice support careless knowledge issues i discussed even though i found ocd category please train listeners properly',
#  'boy super buggy slow slow fact sure still running not the listeners nice generally that is actually connect one it shows many listeners available active and very pushy constantly trying get pay therapist app',
#  'this absolutely amazing it heals helps anxiety depression its hard people say stop wimp theres people real problems thoose problems it feels nice vent everything once',
#  'simple way view eating get better idea habits for reason though crashes girlfriend i every single time open it we open it close error open again every time its infuriating hasnt updated year i dont know still developed abandonware theyre still happy charge month though',
#  'good appwhen works often repeats error messages closes abruptly',
#  'could open week constant crashes no response developers fb page however works great',
#  'was pointless downloading it i installed find day free trial start paying monthly',
#  'i enjoy app wish crash every time i try go back it',
#  'havent able open ver week',
#  'not great business model it listed free really not ive using since twogrand ive loved it im disappointed fee mislabeled free id rather free ads option pay ad free version',
#  'this used free called two grand you could see others meals they changed many times sucks ',
#  'says completely free not its free days per month i get free days completely implies without restriction works fine taking pictures food',
#  'i like pace variety i hear timer music playing it mute music updates nice app',
#  'superb appoffice goin staffbusinessmanwe have less time mints exercise keep body fitthis acts like instructoru enjoy itgood',
#  'this great reminds workout it tailored ability i wish preview workouts video form starting workout',
#  'so far good it got everything i need simple well illustrated exercises lite voice timing it stays i might tempted get ad free version soon',
#  'i love app really keeps motivated better physically super easy home',
#  'should put timmings hard plan fr completed within minutes idea wen rest within exercise',
#  'few blips audioimages great quick way stay little active',
#  'i loved too much interesting easy without need go gym',
#  'just first time i feel exhausted good job',
#  'great app minutes definately makes sweat',
#  'its good want exercise',
#  'bland boring even paid level not recommended till add features wish fields new habit section add details also ability colour code habits organize better perhaps category section sort habits ie habits improve school life work life etc uninstalling till things added',
#  'minimalistic effecient the exactly advertises the design sleek instructions clear i switched another complicated objective tracker such working times week date night week optional skip days that rewire tad better management but tired while',
#  'wonderful this done amazing things perfectionist attitude i used make long impossible complete lists i finish everyday i felt like failure now i list couple things i finish days finally from time time add couple new things im able finish lists too i feel free failing everyday thank much creating app',
#  'this worked wonders me the problem i find i think current day bit lagged behind sometimes i get early still highlights previous day but big issue aside perfect highly recommended anyone wants track habits',
#  'small bug i yet start really using concept seems good i set habit start date week now yet im getting daily notifications like you it while i appreciate motivational spirit save habit start date',
#  'been using whole year almost everyday goddamn i cant without this i write reviews often deserves praise given amazing app intuitive easy use ',
#  'great concept but i also think thing front everyday feel like it like look positive way doing pushups best target smoking anything adviced maybe developers take innovative way think solution ',
#  'i like it tried habit bull fabulous me etc the interface workflow much focused overwhelm but thing almost habit trackers missing complement i hope weeks among first since ive invested bought premium version',
#  'i think great app but much cheaper calendar phone notebook to i think worth money but great concept tho especially people really struggle bad certain addictions much love app but im uninstalling thank tho ',
#  'i bought plus version i love it great alternative notecard i actively widget suggestions when reach end habit the habitbreaking time set creation habit says youve completed habit forces reset it i wish could choose continue indefinitely that without time goal set also set habitbreaking time mark lot days incomplete end time still see youve completed habit really true i wish punishment incomplete days severe maybe time goal reset maybe something less dramatic',
#  'its habit trackerhabit motivation allows name make personal habit like i wanted upgrade clash clans buildings every morning wont let name habit make own so stars',
#  'completing goal gives red x usually negative symbol i feel good seeing all there also seem way set goals specific days every day this means im forced break streak i take rest day making feel bad',
#  'noughts crosses when achieves task assigns x day o missing it can changed lots crosses look like lots wrongs therefore lots misses the circles end looking positive why cant i choose icon or green circle achieved red missed',
#  'its great app simple clear the reminders really helpful really helping change habits one thing id like would able alternate days so yoga day running next',
#  'the better pool game google play slightly buggy when opponents connection stable suddenly says i run time even though i made shot it also seem support push out the timer needs b obvious runs out',
#  'hate get cue pieces maxed cue really wish guys would change that keep getting n hr boxes cairo delhi n end getting pieces i use complete waste time change n review goes back stars',
#  'games alright bit sketchy either opponent bad connection the pool cue power bar needs look at its annoying im trying get right amount power suddenly starts moving angle finger moved bar',
#  'hi really like game i tried ti purchase halloween pack twice amount got deducted bank account transaction pool showed declined could u please let knw whether get pack money back',
#  'worst servers iran from first time i tried game i acoutered message connection slow i tried best networks iran recently even connect game time please consider better servers cause many iranians love game',
#  'i previous profile however updates i lost million coins rank how sad frustrating i start again if ball fix ill give five stars',
#  'love game im issues requesting gifts club advise i restarted phone closed opened even checked updates any help would great worked fine today',
#  'so wanted enjoy game hacked death many people become boring you pot ball back u started turn super fast fiber bb connectionits badly maintained app',
#  'really love i wish like real pool if sink stripe break stripes and sucks getting beat someone shooting random winning shoot full power hoping sink balls every pocket called other i love',
#  'really what i think game awesome i play table pool time this game real life pool people complaining control developers fault individual fault if know manipulate easy pool peace men',
#  'sorry greedy i love game since i started now club created go different club the game would outstanding happens i rated star get attention sorry',
#  'really good addictive game me girlfriend constantly playing downfall sometimes watch videos free money dont emd getting it has happened numerous times great game',
#  'game cuts sometimes u loose turn sometimes causes match loss also spend money recharge stick whats about i play real bca pool a effort b effect',
#  'i actually addicted game seemed wierd critical times game i going win match game shuts time i get rebooted ive lost only time ever critical moments ill never play again promise that the game totally rigged thats perfectly clear spin wheel always lands low s whats chances otherwise rigged',
#  'i have used the daily spin times i never got coins game tells buy better spin same boxs so shame not fair not fair seriously out many spins get nothing good i unlucky',
#  'i hundred coins i new i even i winning games player backing i played i waited player back i still getting extra coins winning so going able play day till i build coins',
#  'the indians cheat you see can option choose opponents based i wish play million cheating indians permantly online',
#  'i installed trip i thought i would wifi i didnt so i decided practice offline mode sadly ingame money play offline i want waste it when i got back i tried actual game working fine middle game closed itself did i mention takes forever load by time i got back i already lost this happened i lost money i really feel like playing anymore',
#  'it made chickens eat mice too many convenient bugs big games free spins joke why i wait opponents response lots flaws not sure rigged seems like',
# ...
#  'this fantastic provides many workout videos choose even specific ones target certain areas best no ads love it',
#  'honestly really great start someone overweight unfit looking change lifestyle',
#  'i recently started using app i really enjoy it its suited personal goals needs perfect',
#  'i truly delighted i needed able get back shape yoga lessons send incredibly free mind state this amazing',
#  'wow second day im sweaty',
#  'a fab way getting daily exercise in aside certain extras meal plan completely free',
#  'easy start much start eventually ramp more meal planning super helpful love notifications keep accountable',
#  'short intense workouts perfect someone whos ready spend hours gym lots cash fitness plan',
#  'i really enjoying keeping game requires lot less thinking i stay focused',
#  'im day very easy follow realistic goals suit needs so far great',
#  'great beginners workout wanting start gym do days first add gym next days',
#  'great daily workouts moms much time workout i mine i put little bed',
#  'this good ive finally found combines meal plan exercise plan the meals delicious workouts invigorating',
#  'love shows exercises love usually less minutes great busy person',
#  'excellent lots choices different exercises depending needs are nice fresh easy meal ideas always fun motivating',
#  'great app i love guidance quick demos correct way exercise the structure workout routine helps',
#  'easy follow you certainly feel burn great ready exercise need help so',
#  'awesome app easy follow creative fulfilling workouts im really happy i chose fit',
#  'its good app need visit gym cos exercises something home',
#  'great keep accountable give diet exercise perfectly match goals i highly recommend it',
#  'loving app the meal plans great the recipes awesome the exercises easy follow im feeling better im already seeing results',
#  'great app easy use easy video instructions needed exercise you set reminder next day',
#  'great fitness level i like change routine every day get boring',
#  'love free version probably going pay pro version soon definitely great way work strength cardio well',
#  'its perfect beginners challenging gives results stay constant trust process',
#  'makes fun easy work longest work ive mins perfect working mom',
#  'just started this so far clean simple intuitive good meal plans workouts going stick while',
#  'love app easy straight forward tailor fit schedule meal plans amazing tasty',
#  'i loving it it really improved daily routine helped keep daily',
#  'challenging pushing limits without overstepping enough make sweat work it push harder great app',
#  'love reminds work out tracks progress gives exercises try choice own',
#  'amazing app the workouts based skill level super helpful whatever personal goal is',
#  'i know chinese wish english version app this best google play store',
#  'recharged but didnt make any money but also deducted my money what happened trouble what is the problem',
#  'what i think i mite find beautiful lady every wear',
#  'gay app using english translation',
#  'it makes happy positive',
#  'seesex',
#  'the card is terrible complaining about the customer service they have no way bad',
#  'is there dew point',
#  'the picture is too small',
#  'like',
#  'creepy if like watching people put makeup go ahead weirdos also comment guarantee racist response developer wait lol',
#  'im sorry i seen',
#  'stupid appjust chineseactually bad',
#  'ling ling lang lee lim low lo li ho ching chong dumpling',
#  'always stay alive',
#  'i think lovely xxx',
#  'understand chinese you',
#  'nice n fun',
#  'not sexy enough cant see breast portom',
#  'please fix it wait for minutes still buffering still cant get into this app it has been buffering in the interface',
#  'not english stop finding way around using pictures its chinese cam model app',
#  'waste people singing english',
#  'not sexy enough i wanted girl open bra panty looks sexy',
#  'i wish change language',
#  'sx',
#  'i wanted write company say reading notes sound like bunch racists please chinese damn racists',
#  'stupid chinese girlsso boring',
#  'no need to see girls naked bad live broadcast',
#  'why arent women naked give some ids ',
#  'only written chinese',
#  'i enjoyed days apps but things happen today i cant see comments send gift please fix',
#  'i love even speak chinese u guys plz make english give u ',
#  'hi i lost account how i retrieve it is email write to',
#  'very strange sure knew showing youtube english speaking tubers maybe thats confusion im sure nice',
#  'bad',
#  'i like it let register guest login when i said naughty santa shuldnt say i knew good something positive im good year now kids think abt santa since call request i many others feel same full review',
#  'sorry i got things i review it let sign reason i put username said username found i tried message santa i tried many times put username i clicked guest i happy i started type i sent message santa i waiting hour still answer first time trying i demastated',
#  'if two things i would love give five stars mostly fantastic but i request call santa way make naughty list call it says oh i knew good year makes happy great good bad bad and second thing real pause respond just long enough it would nice could say name too but im grateful part',
#  'this worst no answered im disappointed answered text call back fake do not install this stupid app',
#  'not bad however trouble registering enter username password register looked like notification flashes screen once literally quick even see anything it looks like gray box flashes button loginif active account',
#  'i thought wonderful santa actually answered loved got tell wanted christmas the thing tried calling twice went voice mail thank you',
#  'rubbish stupid spends minutes text allowances even though says free dont download and even real wants stupid',
#  'disappointed we tried send message kept saying no message entered no phone call ever happened either',
#  'its ok best i think good little children feel involved santa theme text santa ring him i think ring santa talks quick give ppl enough time give full answer ',
#  'really clever this really clever the text good how come i reply text santa i tried minute ago',
#  'great it exactly i needed do its got breaks long enough child actually answer',
#  'id love wasnt ads i mean allows adult ads on kids flipn ridiculous',
#  'obviously santa real sisters fooled they loved it they terrified naughty list',
#  'i love guys voice pause enough my son tried tell santa wanted christmas seconds say it',
#  'i think different accent current would better something santa clausy rather middle american accentto expand could make multi lingual expand languages next year that make better its also great ensure kids full review',
#  'oh goodness i think amazing little sister cute talking santa i think works great i love message idea voice mail request call adorable reason stars i wish santa could talk bit lil sis',
#  'fake santa asking questions i even say anything still asking questions scam text ur personal information ask real santa clause real santa claus see u ur information',
#  'this pretty cool whenever friend santa claus real said yes also asked ive nice list versus nice list said yeah i knew good also good i wish little kids hit like par full review',
#  'i love santa says hes happy nice child but like fact daughter naughty',
#  'i miss old santa claus north pole cant choose favorite foods sports input name age real feel',
#  'in opinion okay however i would enjoy i couldve answered papa noëls questions pause long enough overall i much enjoyed',
#  'its way boring press button wait till calls like right seconds',
#  'scar kids life putting naughty list getting call santa worth every star reactions',
#  'will let set account not sure messages get response not trying kid it',
#  ' stars get call santa recorded message i said nothing kept playing bad get waste time',
#  'my son figured fake it give time kid answer he keeps talking my son figured recording stopped talking recording kept playing',
#  'this no its pretty bad keeps saying i call ends call right disappointed',
#  'i love i get call santa i problems i cant talk goes voicemail i get making toys girls boys santa answer messages',
#  'saying bad things i got call santa im i give happened five stars kentucky yeah',
#  'awful like i awful like right like annoying like listen anything saying',
#  'dislike cant register help page ask questions would really good could ',
#  'i thought quite scary creators number weird said name i acc',
#  'not great want know os say u call doesnt answer messages',
#  'i put brother naughty list freaked i got trouble still good',
#  'awordaday only problem keep date',
#  'great would even better selection page displayed diacritics properly fix stars ',
#  'nice i love it its handy i need new words college papers',
#  'not really word day more like couple words every week so',
#  'its actually really good app im ddisappointed show i watch cant watched here but it so i happy not ads just commercial based like tv i understand complaints i see bugs ads nothing u see cable its add phone this surprisingly top notch',
#  'the commercial interrupt show sync shows watched tv even though log cable account',
#  'more commercials watching live ones over then replay sit them shuts least x per day',
#  'i love app though wish option episodes way watch dont internet',
#  'was pleased easy great quality',
#  'so so many pop up ads',
#  'the content good takes forever load spend time waiting watching',
#  'its easy use quite ads i wish almost every video wasntlocked cool like',
#  'its great i wish unlocked shows',
#  'i love life pd',
#  'i love dog family i need please able unlock episodes help',
#  'too many advertisements',
#  'cant watch anything keeps saying need reauthenticate then blank screen',
#  'just tiny bit lag overall really great',
#  'i love able watch favorite shows directly phone',
#  'i liked it was able watch billy exterminator full episodes seasons',
#  'its i thought would',
#  'this great runs smooth plenty content the reason gets stars because sometimes probably times week lock shows lock next them so i enter usernamepassword unlock them this annoying drawback me but trying drag mud it still great lot interesting shows solid stars always room improvement',
#  'more commercials ive ever seen app i even upgraded version unlock episodes episode commercials breaks commercials time love ae way i watch hour episode hour half still want watch',
#  'the commercials absolutely ridiculous in minute episode commercial breaks commercials piece',
#  'the many ads episodes free i seriously disappointed app',
#  'its clear runs smoothmy issue u stop watching show come back later goes directly double long commercial break',
#  'ads way loud i deaf i tends bit clunky needs better programming',
#  'it take long submit night befores shows if internet possibly access previous show if not appits literally toss up not exactly fair book whether i internet home cell',
#  'i cant watch it',
#  'love app first life',
#  'enjoy watching shows ive missed tv',
#  'i dropped rating as last update i longer delete photos what happened i often take extra pics order choose right delete extra now i cannot delete memory filling unwanted unneeded pics some i try delete multiplying please fix back old version ',
#  'the good but i problems i cannot remove album cover set i change another picture please fix this when selecting pics right column scroll bar gets activated tone this irritating since scroll way back were',
#  'installed x put shortcut home screen therefore unusable since i find launch it really stupid',
#  'i love much better gallery apps',
#  'entire album corrupted opening i lost friends photos i disappointed app',
#  'apps good add very bad',
#  'it got many features phto editing features good',
#  'not good nothing good with nothing',
#  'alert july th contains contain virus gone missing devices might security virus program still remains google play store ',
#  'i try a lot before choosing this application it is the best even the photos are covered by gps wawww',
#  'need option group photos main page easily searchable if need description feature i explain you',
#  'ok good job catches areas images be problem though certain used editing that love it',
#  'i cannot see photos videos',
#  'this would great gallery if would let rename photos but since wont i uninstalled it',
#  'back starscant save travel photo says please try again later every timenot sure thats possible',
#  'organised scattered images videos place ',
#  'worlds worst photo gallery',
#  'it was very good that it was better than simple',
#  'i like vault i heard contests that might fun i photo restoration composite imagery illustration design',
#  'alphabetical album sorting simple requirement missing pré installed gallery a',
#  'i want a refund idea multiple select album menu exclude album',
#  'awesome features nice working i like much',
#  'please dont give add',
#  'sometimes hangs ads distracting',
#  'i am very pleased with this thanks to many thanks',
#  'so many ads i cant actually anything',
#  'good nokia thanks developers',
#  'god tugel bakhakh gork njordi',
#  'i like every body like',
#  'good app i searching type app',
#  'this is nice im enjoy feel',
#  'nothing make slides video',
#  'it worth pay',
#  'i like much',
#  'open whatsapp messenger',
#  'overall great app best gallery seen far',
#  'recommended love it keep good work dev ',
#  'too much ads',
#  'just allow time ',
#  'its good best gallery phone',
#  'i rated higher lowering rating it simply work times bill pay screen ask pay screen blank cant navigate main screen once goes south navigation worthless log back in repeats again ui needs work',
#  'it tells i need update option update so i uninstall try open itnothing i cant open app this day critical i able know whats accounts fix now aplus',
#  'issues remembering device fingerprint scan always work once get logged however fine',
#  'the mobile check deposit ia add easy',
#  'being prompted rate time already rated annoying',
#  'longer opens xperia xz its broke',
#  'this really good way manage bank accounts pay bill plus bank account tech support awesome i love a ',
#  'this best bank ever dont take word stop a federal credit union bank ask',
#  'the needs the look design bad',
#  'often site doesnt load initial login i exit try later much later',
#  'i love able check balance transfer money deposit checks account time day night',
#  'i love makes life lot easier every little buggy',
#  'extremely userfriendly i really appreciate able view history payments',
#  'it works well time sometimes open logging in',
#  'i absolutely love howsimple keep three accounts transfer funds etc',
#  'i love a federal credit union the everything i need do thank you',
#  'can laggy times generally works good',
#  'i love helps stay touch purchases account activity absolutely best',
#  'this great i everything palm hands thank whole branch',
#  'i like access accounts fingertips',
#  'i really like helps alot',
#  'i private anywhere no call automated system everything app',
#  'i absolutely love it the ease able transfer money member member outstanding',
#  'please fix font update letters huge',
#  'its easy way check balances pay bills transferring money',
#  'the a plus mobile great easy navigate',
#  'easy use deposit checks check balances quickly fingerprint id great',
#  'i really enjoy keeping account info',
#  'i take care banking',
#  'this user friendly i love it',
#  'i love afcu member years',
#  'simple yet packed lot full functions',
#  'great check accounts go',
#  'simple easy like desktop version',
#  'nice convenient easy',
#  'good keep account',
#  'needs serious update modern day efficiency',
#  'its okay',
#  'awesome really easy use',
#  'i issues',
#  'helpful check balance go',
#  'make life easy',
#  'thank',
#  'i love everything plus',
#  'keeps improving yay',
#  'its useful balance checks',
#  'love it fast easytouse',
#  'i love bank',
#  'is easy convenient',
#  'i love a plus',
#  'great app simple point',
#  'awesome thank you',
#  'great convenient',
#  'makes life easier',
#  ...]

# %%
df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 29687  Housing-Real Estate & Property
# 29688  Housing-Real Estate & Property
# 29689  Housing-Real Estate & Property
# 29690  Housing-Real Estate & Property
# 29691  Housing-Real Estate & Property
#
#                                                  Reviews Sentiment  \
# 0      i like eat delicious food thats im cooking foo...  Positive
# 1        this help eating healthy exercise regular basis  Positive
# 2             works great especially going grocery store  Positive
# 3                                           best idea us  Positive
# 4                                               best way  Positive
# ...                                                  ...       ...
# 29687  most ads older many agents not much owner post...  Positive
# 29688  if photos posted portal load fit purpose im su...  Positive
# 29689  dumb app i wanted post property rent give opti...  Negative
# 29690  i property business got link sms happy perform...  Positive
# 29691  useless app i searched flats kondapur hyderaba...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                0.400000                0.875000
# 3                1.000000                0.300000
# 4                1.000000                0.300000
# ...                   ...                     ...
# 29687            0.173333                0.486667
# 29688            0.225000                0.447222
# 29689           -0.287500                0.250000
# 29690            0.800000                1.000000
# 29691           -0.316667                0.400000
#
# [29692 rows x 5 columns]

# %% [markdown]
# *The punctuation marks have been cleaned in the dataset*

# %% [markdown]
# #### Tokenizing the Reviews

# %%
from nltk.tokenize import word_tokenize
df['Reviews'].dropna(inplace=True)
df['Reviews'] = df['Reviews'].apply(word_tokenize)

# %%
df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 29687  Housing-Real Estate & Property
# 29688  Housing-Real Estate & Property
# 29689  Housing-Real Estate & Property
# 29690  Housing-Real Estate & Property
# 29691  Housing-Real Estate & Property
#
#                                                  Reviews Sentiment  \
# 0      [i, like, eat, delicious, food, thats, im, coo...  Positive
# 1      [this, help, eating, healthy, exercise, regula...  Positive
# 2      [works, great, especially, going, grocery, store]  Positive
# 3                                       [best, idea, us]  Positive
# 4                                            [best, way]  Positive
# ...                                                  ...       ...
# 29687  [most, ads, older, many, agents, not, much, ow...  Positive
# 29688  [if, photos, posted, portal, load, fit, purpos...  Positive
# 29689  [dumb, app, i, wanted, post, property, rent, g...  Negative
# 29690  [i, property, business, got, link, sms, happy,...  Positive
# 29691  [useless, app, i, searched, flats, kondapur, h...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                0.400000                0.875000
# 3                1.000000                0.300000
# 4                1.000000                0.300000
# ...                   ...                     ...
# 29687            0.173333                0.486667
# 29688            0.225000                0.447222
# 29689           -0.287500                0.250000
# 29690            0.800000                1.000000
# 29691           -0.316667                0.400000
#
# [29692 rows x 5 columns]

# %% [markdown]
# *The Reviews have been tokenized i.e. split into tokens/pieces*

# %% [markdown]
# #### Removing the stop words from Reviews

# %%
#nltk.download('stopwords')
from nltk.corpus import stopwords

# %%
stopwords = stopwords.words('english')

# %%
def remove_stopwords(text):        
    words = [w for w in text if w not in stopwords]
    return words


df['Reviews'] = df['Reviews'].apply(lambda x: remove_stopwords(x))

# %%
df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 29687  Housing-Real Estate & Property
# 29688  Housing-Real Estate & Property
# 29689  Housing-Real Estate & Property
# 29690  Housing-Real Estate & Property
# 29691  Housing-Real Estate & Property
#
#                                                  Reviews Sentiment  \
# 0      [like, eat, delicious, food, thats, im, cookin...  Positive
# 1      [help, eating, healthy, exercise, regular, basis]  Positive
# 2      [works, great, especially, going, grocery, store]  Positive
# 3                                       [best, idea, us]  Positive
# 4                                            [best, way]  Positive
# ...                                                  ...       ...
# 29687  [ads, older, many, agents, much, owner, posted...  Positive
# 29688  [photos, posted, portal, load, fit, purpose, i...  Positive
# 29689  [dumb, app, wanted, post, property, rent, give...  Negative
# 29690  [property, business, got, link, sms, happy, pe...  Positive
# 29691  [useless, app, searched, flats, kondapur, hyde...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                0.400000                0.875000
# 3                1.000000                0.300000
# 4                1.000000                0.300000
# ...                   ...                     ...
# 29687            0.173333                0.486667
# 29688            0.225000                0.447222
# 29689           -0.287500                0.250000
# 29690            0.800000                1.000000
# 29691           -0.316667                0.400000
#
# [29692 rows x 5 columns]

# %% [markdown]
# *The sopwords have been removed from Reviews*

# %% [markdown]
# #### Lemmatization of Reviews

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

def word_lemmatizer(text):
    lem_text = [lemmatizer.lemmatize(i) for i in text]
    return lem_text


df['Reviews'] = df['Reviews'].apply(lambda x: word_lemmatizer(x))

# %%
df['Reviews'].head(10)
# Out:
# 0    [like, eat, delicious, food, thats, im, cookin...
# 1    [help, eating, healthy, exercise, regular, basis]
# 2     [work, great, especially, going, grocery, store]
# 3                                      [best, idea, u]
# 4                                          [best, way]
# 5                                            [amazing]
# 6                              [looking, forward, app]
# 7                     [helpful, site, help, food, get]
# 8                                               [good]
# 9    [useful, information, amount, spelling, error,...
# Name: Reviews, dtype: object

# %% [markdown]
# #### Determining sentiment polarity and subjectivity using TextBlob library

# %%
from textblob import TextBlob

# %%
pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity

# %%
df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 29687  Housing-Real Estate & Property
# 29688  Housing-Real Estate & Property
# 29689  Housing-Real Estate & Property
# 29690  Housing-Real Estate & Property
# 29691  Housing-Real Estate & Property
#
#                                                  Reviews Sentiment  \
# 0      [like, eat, delicious, food, thats, im, cookin...  Positive
# 1      [help, eating, healthy, exercise, regular, basis]  Positive
# 2       [work, great, especially, going, grocery, store]  Positive
# 3                                        [best, idea, u]  Positive
# 4                                            [best, way]  Positive
# ...                                                  ...       ...
# 29687  [ad, older, many, agent, much, owner, posted, ...  Positive
# 29688  [photo, posted, portal, load, fit, purpose, im...  Positive
# 29689  [dumb, app, wanted, post, property, rent, give...  Negative
# 29690  [property, business, got, link, sm, happy, per...  Positive
# 29691  [useless, app, searched, flat, kondapur, hyder...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                0.400000                0.875000
# 3                1.000000                0.300000
# 4                1.000000                0.300000
# ...                   ...                     ...
# 29687            0.173333                0.486667
# 29688            0.225000                0.447222
# 29689           -0.287500                0.250000
# 29690            0.800000                1.000000
# 29691           -0.316667                0.400000
#
# [29692 rows x 5 columns]

# %%
df['Reviews'] = df['Reviews'].apply(lambda x: " ".join(x))

# %%
df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 29687  Housing-Real Estate & Property
# 29688  Housing-Real Estate & Property
# 29689  Housing-Real Estate & Property
# 29690  Housing-Real Estate & Property
# 29691  Housing-Real Estate & Property
#
#                                                  Reviews Sentiment  \
# 0      like eat delicious food thats im cooking food ...  Positive
# 1             help eating healthy exercise regular basis  Positive
# 2              work great especially going grocery store  Positive
# 3                                            best idea u  Positive
# 4                                               best way  Positive
# ...                                                  ...       ...
# 29687  ad older many agent much owner posted detail r...  Positive
# 29688  photo posted portal load fit purpose im sure s...  Positive
# 29689  dumb app wanted post property rent give option...  Negative
# 29690  property business got link sm happy performanc...  Positive
# 29691  useless app searched flat kondapur hyderabad n...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                0.400000                0.875000
# 3                1.000000                0.300000
# 4                1.000000                0.300000
# ...                   ...                     ...
# 29687            0.173333                0.486667
# 29688            0.225000                0.447222
# 29689           -0.287500                0.250000
# 29690            0.800000                1.000000
# 29691           -0.316667                0.400000
#
# [29692 rows x 5 columns]

# %%
df['Predicted_Polarity'] = df['Reviews'].apply(pol)
df['Predicted_Subjectivity'] = df['Reviews'].apply(sub)

# %%
df.head(10)
# Out:
#                      App                                            Reviews  \
# 0  10 Best Foods for You  like eat delicious food thats im cooking food ...
# 1  10 Best Foods for You         help eating healthy exercise regular basis
# 2  10 Best Foods for You          work great especially going grocery store
# 3  10 Best Foods for You                                        best idea u
# 4  10 Best Foods for You                                           best way
# 5  10 Best Foods for You                                            amazing
# 6  10 Best Foods for You                                looking forward app
# 7  10 Best Foods for You                         helpful site help food get
# 8  10 Best Foods for You                                               good
# 9  10 Best Foods for You  useful information amount spelling error quest...
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity  Predicted_Polarity  \
# 0  Positive                1.00                0.533333                1.00
# 1  Positive                0.25                0.288462                0.25
# 2  Positive                0.40                0.875000                0.40
# 3  Positive                1.00                0.300000                1.00
# 4  Positive                1.00                0.300000                1.00
# 5  Positive                0.60                0.900000                0.60
# 6   Neutral                0.00                0.000000                0.00
# 7   Neutral                0.00                0.000000                0.00
# 8  Positive                0.70                0.600000                0.70
# 9  Positive                0.20                0.100000                0.20
#
#    Predicted_Subjectivity
# 0                0.533333
# 1                0.288462
# 2                0.875000
# 3                0.300000
# 4                0.300000
# 5                0.900000
# 6                0.000000
# 7                0.000000
# 8                0.600000
# 9                0.100000

# %%
df[df['App'] == 'Housing-Real Estate & Property']
# Out:
#                                   App  \
# 29671  Housing-Real Estate & Property
# 29672  Housing-Real Estate & Property
# 29673  Housing-Real Estate & Property
# 29674  Housing-Real Estate & Property
# 29675  Housing-Real Estate & Property
# 29676  Housing-Real Estate & Property
# 29677  Housing-Real Estate & Property
# 29678  Housing-Real Estate & Property
# 29679  Housing-Real Estate & Property
# 29680  Housing-Real Estate & Property
# 29681  Housing-Real Estate & Property
# 29682  Housing-Real Estate & Property
# 29683  Housing-Real Estate & Property
# 29684  Housing-Real Estate & Property
# 29685  Housing-Real Estate & Property
# 29686  Housing-Real Estate & Property
# 29687  Housing-Real Estate & Property
# 29688  Housing-Real Estate & Property
# 29689  Housing-Real Estate & Property
# 29690  Housing-Real Estate & Property
# 29691  Housing-Real Estate & Property
#
#                                                  Reviews Sentiment  \
# 29671  incorrect listing agent show property discus p...  Negative
# 29672  pathetic appall posted lead owner either old p...  Negative
# 29673  waste app property want room hyderabad able fi...  Positive
# 29674  filter useless posted owner show agent approac...  Negative
# 29675  business filter dont work redirect buyer agent...   Neutral
# 29676             filter work searching property useless  Negative
# 29677      want list property sale option please connect   Neutral
# 29678                                               good  Positive
# 29679  awesome app price date awesome app give proper...  Positive
# 29680  worse ever give graphic picture property like ...  Negative
# 29681  horrible app wanted list property get around e...  Negative
# 29682  worst app get nothing time waste update proper...  Negative
# 29683  able set range cr scroll space cr range least ...  Positive
# 29684  nonsensical app doesnt owner posting plus give...   Neutral
# 29685  response support team login unable see active ...  Negative
# 29686  everything old stuff neither clear sold proper...  Positive
# 29687  ad older many agent much owner posted detail r...  Positive
# 29688  photo posted portal load fit purpose im sure s...  Positive
# 29689  dumb app wanted post property rent give option...  Negative
# 29690  property business got link sm happy performanc...  Positive
# 29691  useless app searched flat kondapur hyderabad n...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity  Predicted_Polarity  \
# 29671           -0.025000                0.125000           -0.025000
# 29672           -0.362500                0.625000           -0.362500
# 29673            0.266667                0.375000            0.150000
# 29674           -0.500000                0.200000           -0.500000
# 29675            0.000000                0.000000            0.000000
# 29676           -0.500000                0.200000           -0.500000
# 29677            0.000000                0.000000            0.000000
# 29678            0.700000                0.600000            0.700000
# 29679            0.509375                0.511458            0.509375
# 29680           -0.081250                0.418750           -0.066667
# 29681           -0.528571                0.717262           -0.528571
# 29682           -0.400000                0.250000           -0.400000
# 29683            0.233333                0.550000            0.233333
# 29684            0.000000                0.000000            0.000000
# 29685           -0.377778                0.533333           -0.377778
# 29686            0.021591                0.259470            0.067273
# 29687            0.173333                0.486667            0.091667
# 29688            0.225000                0.447222            0.225000
# 29689           -0.287500                0.250000           -0.287500
# 29690            0.800000                1.000000            0.800000
# 29691           -0.316667                0.400000           -0.170833
#
#        Predicted_Subjectivity
# 29671                0.125000
# 29672                0.625000
# 29673                0.312500
# 29674                0.200000
# 29675                0.000000
# 29676                0.200000
# 29677                0.000000
# 29678                0.600000
# 29679                0.511458
# 29680                0.433333
# 29681                0.717262
# 29682                0.250000
# 29683                0.550000
# 29684                0.000000
# 29685                0.533333
# 29686                0.387576
# 29687                0.483333
# 29688                0.447222
# 29689                0.250000
# 29690                1.000000
# 29691                0.262500

# %% [markdown]
# #### Summary
#
# *The actual and the predicted values of snetiment polarity and subjectivity are very close to each other for the respective applications.*
